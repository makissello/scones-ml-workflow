# %% [markdown]
# # Deploy and monitor a machine learning workflow for Image Classification

# %% [markdown]
# ## Setting up this notebook
#
# Notes about the instance size and kernel setup: this notebook has been tested on
#
# 1. The `Python 3 (Data Science)` kernel
# 2. The `ml.t3.medium` Sagemaker notebook instance
#
# ## Data Staging
#
# We'll use a sample dataset called CIFAR to simulate the challenges Scones Unlimited are facing in Image Classification. In order to start working with CIFAR we'll need to:
#
# 1. Extract the data from a hosting service
# 2. Transform it into a usable shape and format
# 3. Load it into a production system
#
# In other words, we're going to do some simple ETL!
#
# ### 1. Extract the data from the hosting service
#
# In the cell below, define a function `extract_cifar_data` that extracts python version of the CIFAR-100 dataset. The CIFAR dataaset is open source and generously hosted by the University of Toronto at: https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz

# %%
import requests

def extract_cifar_data(url, filename="cifar.tar.gz"):
    """A function for extracting the CIFAR-100 dataset and storing it as a gzipped file
    
    Arguments:
    url      -- the URL where the dataset is hosted
    filename -- the full path where the dataset will be written
    
    """
    
    # Todo: request the data from the data url
    # Hint: use `requests.get` method
    r = requests.get("https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz")
    with open(filename, "wb") as file_context:
        file_context.write(r.content)
    return

# %% [markdown]
# Let's test it out! Run the following cell and check whether a new file `cifar.tar.gz` is created in the file explorer.

# %%
extract_cifar_data("https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz")

# %% [markdown]
# ### 2. Transform the data into a usable shape and format
#
# Clearly, distributing the data as a gzipped archive makes sense for the hosting service! It saves on bandwidth, storage, and it's a widely-used archive format. In fact, it's so widely used that the Python community ships a utility for working with them, `tarfile`, as part of its Standard Library. Execute the following cell to decompress your extracted dataset:

# %%
import tarfile

with tarfile.open("cifar.tar.gz", "r:gz") as tar:
    tar.extractall()

# %% [markdown]
# A new folder `cifar-100-python` should be created, containing `meta`, `test`, and `train` files. These files are `pickles` and the [CIFAR homepage](https://www.cs.toronto.edu/~kriz/cifar.html) provides a simple script that can be used to load them. We've adapted the script below for you to run:

# %%
import pickle

with open("./cifar-100-python/meta", "rb") as f:
    dataset_meta = pickle.load(f, encoding='bytes')

with open("./cifar-100-python/test", "rb") as f:
    dataset_test = pickle.load(f, encoding='bytes')

with open("./cifar-100-python/train", "rb") as f:
    dataset_train = pickle.load(f, encoding='bytes')

# %%
# Feel free to explore the datasets

dataset_train.keys()
# Out:
# dict_keys([b'filenames', b'batch_label', b'fine_labels', b'coarse_labels', b'data'])

# %%
dataset_train[b'filenames']
# Out:
# [b'bos_taurus_s_000507.png',
#  b'stegosaurus_s_000125.png',
#  b'mcintosh_s_000643.png',
#  b'altar_boy_s_001435.png',
#  b'cichlid_s_000031.png',
#  b'phone_s_002161.png',
#  b'car_train_s_000043.png',
#  b'beaker_s_000604.png',
#  b'fog_s_000397.png',
#  b'rogue_elephant_s_000421.png',
#  b'computer_keyboard_s_000757.png',
#  b'willow_tree_s_000645.png',
#  b'sunflower_s_000549.png',
#  b'palace_s_000759.png',
#  b'adriatic_s_001782.png',
#  b'computer_keyboard_s_001277.png',
#  b'bike_s_000682.png',
#  b'wolf_pup_s_001323.png',
#  b'squirrel_s_002467.png',
#  b'sea_s_000678.png',
#  b'shrew_s_002233.png',
#  b'pine_tree_s_000087.png',
#  b'rose_s_000373.png',
#  b'surveillance_system_s_000769.png',
#  b'pine_s_001533.png',
#  b'table_s_000897.png',
#  b'opossum_s_001237.png',
#  b'quercus_alba_s_000257.png',
#  b'leopard_s_000414.png',
#  b'possum_s_002195.png',
#  b'bike_s_000127.png',
#  b'balmoral_castle_s_000361.png',
#  b'acer_saccharinum_s_000646.png',
#  b'lapin_s_000916.png',
#  b'chimp_s_001419.png',
#  b'clock_s_002291.png',
#  b'streetcar_s_000663.png',
#  b'male_child_s_000800.png',
#  b'oriental_cockroach_s_000650.png',
#  b'breakfast_table_s_001135.png',
#  b'coluber_constrictor_s_000067.png',
#  b'lobster_s_000034.png',
#  b'mount_s_002852.png',
#  b'wolf_pup_s_001277.png',
#  b'areca_s_000244.png',
#  b'skyscraper_s_000180.png',
#  b'boy_s_001150.png',
#  b'train_s_001640.png',
#  b'tractor_s_001723.png',
#  b'snake_s_000046.png',
#  b'shortfin_mako_s_000172.png',
#  b'butterfly_s_001371.png',
#  b'television_s_000158.png',
#  b'beer_bottle_s_001063.png',
#  b'adriatic_s_002075.png',
#  b'honeybee_s_001911.png',
#  b'red_maple_s_000275.png',
#  b'reclining_chair_s_001157.png',
#  b'black_woman_s_001310.png',
#  b'silver_maple_s_001664.png',
#  b'syrian_hamster_s_000340.png',
#  b'otter_s_000259.png',
#  b'seal_s_001773.png',
#  b'panthera_leo_s_000068.png',
#  b'morchella_esculenta_s_000159.png',
#  b'female_child_s_000292.png',
#  b'bell_pepper_s_001100.png',
#  b'forest_s_001702.png',
#  b'crocodile_s_002505.png',
#  b'valencia_orange_s_000087.png',
#  b'tulip_s_000253.png',
#  b'mus_musculus_s_000005.png',
#  b'arabian_camel_s_000259.png',
#  b'tractor_s_000104.png',
#  b'hamster_s_001554.png',
#  b'caterpillar_s_001005.png',
#  b'bulldozer_s_000433.png',
#  b'man_s_000841.png',
#  b'woods_s_000031.png',
#  b'leopard_s_000033.png',
#  b'keyboard_s_000092.png',
#  b'possum_s_000413.png',
#  b'skunk_s_000825.png',
#  b'kangaroo_s_002457.png',
#  b'cirrocumulus_s_001397.png',
#  b'panthera_pardus_s_000593.png',
#  b'raccoon_s_002740.png',
#  b'garden_snail_s_000513.png',
#  b'mount_s_000051.png',
#  b'caterpillar_s_000450.png',
#  b'man_s_000737.png',
#  b'camel_s_000876.png',
#  b'girl_s_001964.png',
#  b'minuteman_s_000073.png',
#  b'fin_whale_s_000110.png',
#  b'sweet_pepper_s_000921.png',
#  b'manual-skunk007.png',
#  b'nematode_s_000034.png',
#  b'shark_s_002026.png',
#  b'marine_turtle_s_000339.png',
#  b'river_otter_s_000028.png',
#  b'computer_keyboard_s_000598.png',
#  b'castor_fiber_s_000167.png',
#  b'timber_wolf_s_000489.png',
#  b'dessert_plate_s_000192.png',
#  b'turtle_s_000005.png',
#  b'mushroom_s_001005.png',
#  b'icbm_s_000392.png',
#  b'wine_palm_s_000123.png',
#  b'breakfast_table_s_000153.png',
#  b'pinon_pine_s_001228.png',
#  b'didelphis_virginiana_s_000042.png',
#  b'armoire_s_000081.png',
#  b'beaver_s_001511.png',
#  b'boy_s_000081.png',
#  b'forest_s_001481.png',
#  b'route_s_002291.png',
#  b'kangaroo_s_001956.png',
#  b'chaise_s_001222.png',
#  b'forest_s_000144.png',
#  b'fox_s_001040.png',
#  b'flatfish_s_000465.png',
#  b'man_s_000985.png',
#  b'bitter_orange_s_000905.png',
#  b'tiger_s_001271.png',
#  b'eagle_ray_s_000171.png',
#  b'rose_s_001917.png',
#  b'possum_s_000350.png',
#  b'temple_orange_s_000014.png',
#  b'opossum_s_000065.png',
#  b'cycle_s_002598.png',
#  b'salix_alba_s_000332.png',
#  b'television_system_s_001769.png',
#  b'dolphin_s_000421.png',
#  b'lounge_chair_s_001124.png',
#  b'atlantic_bottlenose_dolphin_s_000021.png',
#  b'raccoon_s_001121.png',
#  b'cattle_s_000366.png',
#  b'wtc_s_002253.png',
#  b'television_s_000053.png',
#  b'oak_tree_s_000106.png',
#  b'poppy_s_001932.png',
#  b'missy_s_000260.png',
#  b'hedgehog_s_000950.png',
#  b'discharge_lamp_s_001121.png',
#  b'castor_canadensis_s_000795.png',
#  b'worm_s_001047.png',
#  b'hedgehog_s_000483.png',
#  b'masked_shrew_s_000089.png',
#  b'sour_orange_s_001216.png',
#  b'crab_s_001407.png',
#  b'whale_s_000867.png',
#  b'minibike_s_000824.png',
#  b'nile_crocodile_s_001013.png',
#  b'forest_s_001851.png',
#  b'dinosaur_s_002033.png',
#  b'keyboard_s_001222.png',
#  b'argiope_aurantia_s_000308.png',
#  b'flounder_s_001779.png',
#  b'adam_s_002034.png',
#  b'common_opossum_s_000023.png',
#  b'chalice_s_001706.png',
#  b'tank_s_000640.png',
#  b'plaice_s_000550.png',
#  b'sunflower_s_000444.png',
#  b'snake_s_000451.png',
#  b'keyboard_s_000055.png',
#  b'orchid_s_000878.png',
#  b'cup_s_001227.png',
#  b'raccoon_s_002187.png',
#  b'rabbit_s_001952.png',
#  b'seal_s_001343.png',
#  b'chimp_s_002067.png',
#  b'opossum_s_001219.png',
#  b'poppy_s_001961.png',
#  b'seal_s_000038.png',
#  b'macoun_s_000065.png',
#  b'banded_gecko_s_000650.png',
#  b'beetle_s_000229.png',
#  b'footbridge_s_000052.png',
#  b'cattle_s_001978.png',
#  b'male_child_s_000374.png',
#  b'elephant_s_002362.png',
#  b'saucer_s_001505.png',
#  b'spider_s_000009.png',
#  b'lobster_s_000715.png',
#  b'tram_s_000475.png',
#  b'spider_s_000773.png',
#  b'black_woman_s_000982.png',
#  b'lion_cub_s_000553.png',
#  b'man_s_000436.png',
#  b'numbfish_s_000023.png',
#  b'squirrel_s_001451.png',
#  b'divided_highway_s_001338.png',
#  b'sorex_araneus_s_000172.png',
#  b'motorcycle_s_001856.png',
#  b'streetcar_s_001848.png',
#  b'wardrobe_s_000359.png',
#  b'telephone_set_s_001471.png',
#  b'step_rocket_s_000566.png',
#  b'keyboard_s_000991.png',
#  b'shark_s_000459.png',
#  b'baby_s_000449.png',
#  b'cain_s_000179.png',
#  b'mount_s_000197.png',
#  b'hedgehog_s_000032.png',
#  b'panthera_leo_s_000716.png',
#  b'butterfly_s_000777.png',
#  b'alp_s_002103.png',
#  b'ring_road_s_000322.png',
#  b'rabbit_s_001665.png',
#  b'lawn_mower_s_000052.png',
#  b'house_s_000992.png',
#  b'lobster_s_001705.png',
#  b'hamster_s_001834.png',
#  b'chimp_s_000280.png',
#  b'garden_snail_s_000398.png',
#  b'house_s_000333.png',
#  b'keyboard_s_001475.png',
#  b'bicycle_s_000537.png',
#  b'soda_bottle_s_001739.png',
#  b'poppy_s_002423.png',
#  b'telephone_set_s_000154.png',
#  b'computer_keyboard_s_000417.png',
#  b'cattle_s_001528.png',
#  b'orchid_s_001818.png',
#  b'computer_keyboard_s_001353.png',
#  b'goblet_s_000234.png',
#  b'male_child_s_000659.png',
#  b'tractor_s_000753.png',
#  b'train_s_002155.png',
#  b'train_s_000511.png',
#  b'spider_s_001311.png',
#  b'racoon_s_000375.png',
#  b'tram_s_000405.png',
#  b'chimpanzee_s_001180.png',
#  b'spider_s_001685.png',
#  b'electric_lamp_s_000649.png',
#  b'ankylosaurus_s_001671.png',
#  b'clock_s_000835.png',
#  b'school_bus_s_001438.png',
#  b'sofa_s_000004.png',
#  b'male_child_s_000924.png',
#  b'macropus_giganteus_s_000175.png',
#  b'bowl_s_001230.png',
#  b'salix_alba_s_000012.png',
#  b'orchid_s_000499.png',
#  b'rabbit_s_000297.png',
#  b'keyboard_s_000032.png',
#  b'discharge_lamp_s_000675.png',
#  b'leopard_s_001332.png',
#  b'moped_s_000169.png',
#  b'motorcycle_s_001453.png',
#  b'mushroom_s_001593.png',
#  b'boy_s_002307.png',
#  b'cloud_s_001591.png',
#  b'cloud_s_000856.png',
#  b'bulldozer_s_001774.png',
#  b'shumard_oak_s_000107.png',
#  b'man_s_000926.png',
#  b'infant_s_000851.png',
#  b'bowhead_s_001056.png',
#  b'lion_s_001676.png',
#  b'telephone_set_s_000659.png',
#  b'fox_s_001649.png',
#  b'raccoon_s_000598.png',
#  b'caterpillar_s_000459.png',
#  b'adam_s_002658.png',
#  b'raccoon_s_001641.png',
#  b'date_palm_s_000159.png',
#  b'bartlett_pear_s_000454.png',
#  b'cichlid_fish_s_000335.png',
#  b'gecko_s_000199.png',
#  b'boy_s_001906.png',
#  b'sunflower_s_001373.png',
#  b'cirrocumulus_cloud_s_000515.png',
#  b'railroad_train_s_000200.png',
#  b'palm_tree_s_001513.png',
#  b'cattle_s_000659.png',
#  b'byway_s_000036.png',
#  b'raccoon_s_002225.png',
#  b'goblet_s_000954.png',
#  b'carassius_auratus_s_000432.png',
#  b'bosc_s_000204.png',
#  b'guitarfish_s_000596.png',
#  b'bed_s_001459.png',
#  b'bus_s_000314.png',
#  b'colubrid_s_000836.png',
#  b'bee_s_002016.png',
#  b'table_s_000769.png',
#  b'beetle_s_000181.png',
#  b'mower_s_000031.png',
#  b'lapin_s_002229.png',
#  b'squirrel_s_000142.png',
#  b'drawbridge_s_001392.png',
#  b'mus_musculus_s_001086.png',
#  b'porcupine_s_001592.png',
#  b'dungeness_crab_s_000469.png',
#  b'safety_bike_s_000482.png',
#  b'navel_orange_s_000469.png',
#  b'serengeti_s_001565.png',
#  b'roundworm_s_000036.png',
#  b'grey_wolf_s_001623.png',
#  b'army_tank_s_000896.png',
#  b'red_delicious_s_000552.png',
#  b'worm_snake_s_000429.png',
#  b'elephant_s_002874.png',
#  b'bowl_s_000883.png',
#  b'baby_s_000255.png',
#  b'beetle_s_001769.png',
#  b'lion_s_000032.png',
#  b'sweet_pepper_s_000638.png',
#  b'grey_wolf_s_001289.png',
#  b'trout_s_000574.png',
#  b'sunflower_s_001720.png',
#  b'cup_s_000922.png',
#  b'leopard_s_000559.png',
#  b'northern_spy_s_000602.png',
#  b'sunflower_s_001391.png',
#  b'bed_s_001452.png',
#  b'divided_highway_s_000832.png',
#  b'plain_s_001151.png',
#  b'dolphin_s_001674.png',
#  b'white_woman_s_000709.png',
#  b'sunflower_s_001846.png',
#  b'armchair_s_000265.png',
#  b'possum_s_000343.png',
#  b'raccoon_s_002845.png',
#  b'bowl_s_001218.png',
#  b'skunk_s_000384.png',
#  b'orchid_s_001270.png',
#  b'bosc_s_000883.png',
#  b'tv_s_002465.png',
#  b'raccoon_s_000022.png',
#  b'raccoon_s_000090.png',
#  b'mako_s_001445.png',
#  b'butterfly_orchid_s_001188.png',
#  b'panthera_tigris_s_000539.png',
#  b'panthera_pardus_s_000246.png',
#  b'bungalow_s_000578.png',
#  b'squirrel_s_000430.png',
#  b'tv_s_000033.png',
#  b'bear_s_002131.png',
#  b'ankylosaurus_s_000716.png',
#  b'lion_s_002042.png',
#  b'lift_bridge_s_000070.png',
#  b'shark_s_001047.png',
#  b'golden_willow_s_000013.png',
#  b'cirrocumulus_s_001438.png',
#  b'willow_tree_s_001348.png',
#  b'breakfast_table_s_000858.png',
#  b'oxen_s_001941.png',
#  b'poppy_s_000601.png',
#  b'northern_spy_s_000766.png',
#  b'chimpanzee_s_000577.png',
#  b'male_child_s_001502.png',
#  b'syrian_hamster_s_001413.png',
#  b'opossum_s_001043.png',
#  b'world_trade_center_s_001237.png',
#  b'field_s_001255.png',
#  b'bear_s_000044.png',
#  b'squirrel_s_002376.png',
#  b'sunflower_s_001415.png',
#  b'argiope_aurantia_s_000726.png',
#  b'stone_crab_s_001783.png',
#  b'lapin_s_002654.png',
#  b'seal_s_001016.png',
#  b'male_child_s_001512.png',
#  b'camelus_dromedarius_s_000230.png',
#  b'indian_elephant_s_000094.png',
#  b'dirt_bike_s_000124.png',
#  b'lift_bridge_s_000903.png',
#  b'rainbow_trout_s_000750.png',
#  b'aegean_s_000757.png',
#  b'television_s_002468.png',
#  b'garden_snail_s_000966.png',
#  b'dromedary_s_000084.png',
#  b'tiger_beetle_s_000921.png',
#  b'pickup_s_001180.png',
#  b'mushroom_s_002093.png',
#  b'river_otter_s_000386.png',
#  b'panzer_s_000067.png',
#  b'baby_s_002466.png',
#  b'bear_s_001647.png',
#  b'tractor_s_001465.png',
#  b'bowl_s_000101.png',
#  b'bear_s_002027.png',
#  b'boy_s_000158.png',
#  b'reclining_chair_s_000127.png',
#  b'manual-beaver034.png',
#  b'minibike_s_001863.png',
#  b'crocodile_s_002271.png',
#  b'minibike_s_001177.png',
#  b'beetle_s_001021.png',
#  b'stingray_s_002101.png',
#  b'bear_cub_s_001016.png',
#  b'lapin_s_000097.png',
#  b'palm_tree_s_001619.png',
#  b'soda_bottle_s_000645.png',
#  b'banded_gecko_s_000157.png',
#  b'fin_whale_s_000867.png',
#  b'cain_s_000459.png',
#  b'bell_pepper_s_000991.png',
#  b'rushlight_s_000226.png',
#  b'pickup_s_001808.png',
#  b'surveillance_system_s_001215.png',
#  b'pine_tree_s_000025.png',
#  b'caterpillar_s_000225.png',
#  b'motorcycle_s_001792.png',
#  b'built_in_bed_s_000558.png',
#  b'tiger_s_000274.png',
#  b'dungeness_crab_s_000178.png',
#  b'chimp_s_000637.png',
#  b'oriental_cockroach_s_001588.png',
#  b'valencia_orange_s_000882.png',
#  b'causeway_s_000413.png',
#  b'mount_s_001947.png',
#  b'bulldozer_s_001897.png',
#  b'willow_tree_s_001747.png',
#  b'lady_tulip_s_000107.png',
#  b'tiger_beetle_s_000209.png',
#  b'school_bus_s_000236.png',
#  b'nematode_s_001472.png',
#  b'alp_s_000837.png',
#  b'alarm_clock_s_000740.png',
#  b'palm_tree_s_000276.png',
#  b'stingray_s_001539.png',
#  b'minibus_s_001401.png',
#  b'wolf_pup_s_001918.png',
#  b'apis_mellifera_s_001442.png',
#  b'cattle_s_000150.png',
#  b'world_trade_center_s_000024.png',
#  b'rabbit_s_000039.png',
#  b'pop_bottle_s_001263.png',
#  b'sea_s_000630.png',
#  b'hedgehog_s_001903.png',
#  b'adriatic_sea_s_001411.png',
#  b'caterpillar_s_001744.png',
#  b'river_otter_s_000223.png',
#  b'fox_s_001599.png',
#  b'caterpillar_s_002191.png',
#  b'pearmain_s_000139.png',
#  b'date_palm_s_000021.png',
#  b'cloud_s_000031.png',
#  b'striped_skunk_s_001335.png',
#  b'rose_s_000123.png',
#  b'hognose_snake_s_000782.png',
#  b'lobster_s_001171.png',
#  b'raccoon_s_001131.png',
#  b'trout_s_001341.png',
#  b'couch_s_000195.png',
#  b'pickup_s_000169.png',
#  b'train_s_001419.png',
#  b'pachycephalosaurus_s_001100.png',
#  b'byway_s_001933.png',
#  b'female_child_s_000940.png',
#  b'butterfly_orchid_s_001933.png',
#  b'garden_snail_s_001564.png',
#  b'timber_wolf_s_001336.png',
#  b'red_delicious_s_001189.png',
#  b'rose_s_001126.png',
#  b'striped_skunk_s_001123.png',
#  b'field_s_000442.png',
#  b'rabbit_s_001088.png',
#  b'bed_s_000680.png',
#  b'pickup_s_000872.png',
#  b'sunflower_s_000507.png',
#  b'alp_s_001957.png',
#  b'plate_s_000583.png',
#  b'chalice_s_000481.png',
#  b'banded_gecko_s_000308.png',
#  b'palm_s_001288.png',
#  b'sunflower_s_002364.png',
#  b'fishplate_s_000122.png',
#  b'king_of_beasts_s_001934.png',
#  b'reclining_chair_s_001474.png',
#  b'kangaroo_s_000337.png',
#  b'armoured_combat_vehicle_s_000442.png',
#  b'tv_s_000971.png',
#  b'mount_s_001367.png',
#  b'armored_combat_vehicle_s_000092.png',
#  b'oriental_cockroach_s_000660.png',
#  b'beetle_s_000140.png',
#  b'panthera_tigris_s_000518.png',
#  b'discharge_lamp_s_001205.png',
#  b'kangaroo_s_002432.png',
#  b'seal_s_001302.png',
#  b'oil_palm_s_000902.png',
#  b'beaver_s_000300.png',
#  b'streetcar_s_001199.png',
#  b'black_woman_s_000361.png',
#  b'wolf_pup_s_001346.png',
#  b'butterfly_s_001034.png',
#  b'man_s_001512.png',
#  b'cirrostratus_s_000880.png',
#  b'tractor_s_000670.png',
#  b'phone_s_002177.png',
#  b'bell_pepper_s_000521.png',
#  b'orchid_s_001494.png',
#  b'crocodylus_niloticus_s_000031.png',
#  b'motor_mower_s_000278.png',
#  b'willow_tree_s_002039.png',
#  b'carassius_auratus_s_000240.png',
#  b'streetcar_s_001216.png',
#  b'spider_s_002036.png',
#  b'dolphin_s_001789.png',
#  b'castle_s_002549.png',
#  b'mourning_cloak_s_000845.png',
#  b'guitarfish_s_000177.png',
#  b'recliner_s_001853.png',
#  b'butterfly_orchid_s_000220.png',
#  b'tulip_s_001088.png',
#  b'forest_s_000628.png',
#  b'bartlett_s_000802.png',
#  b'rabbit_s_001687.png',
#  b'alp_s_000839.png',
#  b'adriatic_sea_s_002055.png',
#  b'pine_tree_s_001493.png',
#  b'army_tank_s_000588.png',
#  b'clock_s_002353.png',
#  b'indian_elephant_s_000201.png',
#  b'panzer_s_000006.png',
#  b'palace_s_001469.png',
#  b'panthera_pardus_s_000718.png',
#  b'poppy_s_000707.png',
#  b'crab_s_001193.png',
#  b'field_s_001814.png',
#  b'nile_crocodile_s_001648.png',
#  b'anjou_s_000404.png',
#  b'oxen_s_001496.png',
#  b'wolf_cub_s_001051.png',
#  b'tiger_s_000719.png',
#  b'bowl_s_000643.png',
#  b'elephant_s_002867.png',
#  b'cloud_s_000879.png',
#  b'table_s_002781.png',
#  b'shrew_s_000446.png',
#  b'porcupine_s_000275.png',
#  b'armoire_s_000304.png',
#  b'snail_s_002283.png',
#  b'train_s_001132.png',
#  b'field_s_001105.png',
#  b'bed_s_001805.png',
#  b'cichlid_fish_s_000840.png',
#  b'saucer_s_000150.png',
#  b'right_whale_s_000132.png',
#  b'plaice_s_000350.png',
#  b'balaenoptera_physalus_s_000007.png',
#  b'pear_s_001156.png',
#  b'plaice_s_000110.png',
#  b'cirrostratus_s_000901.png',
#  b'computer_keyboard_s_002296.png',
#  b'lobster_s_002082.png',
#  b'lawn_mower_s_000203.png',
#  b'research_rocket_s_000047.png',
#  b'tractor_s_001897.png',
#  b'lobster_s_000076.png',
#  b'silver_maple_s_001252.png',
#  b'bartlett_pear_s_000444.png',
#  b'boy_s_002179.png',
#  b'minibike_s_001969.png',
#  b'shrew_s_001585.png',
#  b'baby_s_001993.png',
#  b'boy_s_001803.png',
#  b'balaenoptera_physalus_s_000115.png',
#  b'field_mouse_s_000921.png',
#  b'house_s_000981.png',
#  b'pine_s_000436.png',
#  b'adriatic_s_002852.png',
#  b'breakfast_table_s_001147.png',
#  b'dozer_s_000609.png',
#  b'breakfast_table_s_001484.png',
#  b'rose_s_001319.png',
#  b'soda_can_s_000473.png',
#  b'adriatic_sea_s_000597.png',
#  b'velocipede_s_001585.png',
#  b'moped_s_000035.png',
#  b'elephant_s_002404.png',
#  b'eve_s_000004.png',
#  b'plaice_s_000047.png',
#  b'baby_s_002128.png',
#  b'water_shrew_s_000191.png',
#  b'poppy_s_001264.png',
#  b'sea_s_002165.png',
#  b'train_s_001394.png',
#  b'red_fox_s_000435.png',
#  b'disciotis_venosa_s_000196.png',
#  b'macoun_s_000441.png',
#  b'lift_bridge_s_000420.png',
#  b'crab_s_002209.png',
#  b'bartlett_pear_s_000233.png',
#  b'poppy_s_001733.png',
#  b'bartlett_pear_s_000472.png',
#  b'indian_elephant_s_000796.png',
#  b'rabbit_s_001146.png',
#  b'yellowtail_flounder_s_000243.png',
#  b'coffee_can_s_001622.png',
#  b'little_girl_s_000041.png',
#  b'black_woman_s_001350.png',
#  b'male_child_s_001793.png',
#  b'tv_s_001357.png',
#  b'kangaroo_s_002285.png',
#  b'oak_tree_s_000047.png',
#  b'bulldozer_s_000838.png',
#  b'discharge_lamp_s_001516.png',
#  b'wtc_s_002086.png',
#  b'tiger_beetle_s_000003.png',
#  b'butterfly_orchid_s_000865.png',
#  b'skyscraper_s_001185.png',
#  b'delphinus_delphis_s_000307.png',
#  b'pine_tree_s_001916.png',
#  b'breakfast_table_s_001115.png',
#  b'bear_cub_s_000055.png',
#  b'rainbow_trout_s_001311.png',
#  b'man_s_001569.png',
#  b'lapin_s_000175.png',
#  b'lion_s_001571.png',
#  b'mount_s_002677.png',
#  b'apis_mellifera_s_000067.png',
#  b'forest_s_001829.png',
#  b'bunk_s_000515.png',
#  b'butterfly_s_001030.png',
#  b'garden_snail_s_001207.png',
#  b'flying_gecko_s_000107.png',
#  b'byway_s_001963.png',
#  b'sunflower_s_001371.png',
#  b'wardrobe_s_000411.png',
#  b'raccoon_s_002036.png',
#  b'shark_s_001677.png',
#  b'palm_tree_s_002039.png',
#  b'dozer_s_000602.png',
#  b'valencia_orange_s_000296.png',
#  b'clock_s_002064.png',
#  b'test_rocket_s_000008.png',
#  b'brown_snail_s_000254.png',
#  b'breakfast_table_s_000906.png',
#  b'lounge_chair_s_000324.png',
#  b'black_woman_s_000116.png',
#  b'castor_fiber_s_000296.png',
#  b'exocet_s_000171.png',
#  b'spider_s_001955.png',
#  b'lamp_s_001826.png',
#  b'lobster_s_000381.png',
#  b'cichlid_fish_s_000302.png',
#  b'feather_palm_s_000112.png',
#  b'lapin_s_000922.png',
#  b'verpa_s_000264.png',
#  b'bed_s_001238.png',
#  b'squirrel_s_002181.png',
#  b'orchid_s_000751.png',
#  b'dwarf_tulip_s_000093.png',
#  b'castor_fiber_s_000472.png',
#  b'cirrocumulus_cloud_s_000273.png',
#  b'field_s_000026.png',
#  b'streetcar_s_002138.png',
#  b'snail_s_000896.png',
#  b'shark_s_002270.png',
#  b'black_woman_s_000156.png',
#  b'red_delicious_s_000750.png',
#  b'butterfly_s_000833.png',
#  b'jug_s_000102.png',
#  b'gecko_s_000722.png',
#  b'crocodile_s_000007.png',
#  b'bike_s_000256.png',
#  b'panthera_leo_s_001721.png',
#  b'neomys_fodiens_s_000035.png',
#  b'cain_s_000133.png',
#  b'wardrobe_s_001407.png',
#  b'desk_phone_s_000500.png',
#  b'dolphin_s_000768.png',
#  b'dessert_plate_s_000127.png',
#  b'bartlett_pear_s_000211.png',
#  b'male_child_s_000715.png',
#  b'streetcar_s_001157.png',
#  b'sofa_s_000606.png',
#  b'streetcar_s_001417.png',
#  b'rose_s_000222.png',
#  b'stegosaurus_s_001600.png',
#  b'crocodylus_niloticus_s_000032.png',
#  b'bear_s_001186.png',
#  b'adriatic_sea_s_000395.png',
#  b'tangerine_s_000443.png',
#  b'minibike_s_000571.png',
#  b'cattle_s_000459.png',
#  b'squirrel_s_002089.png',
#  b'bartlett_s_000838.png',
#  b'cattle_s_000041.png',
#  b'pine_s_002190.png',
#  b'sofa_s_000047.png',
#  b'wine_palm_s_000179.png',
#  b'sorex_cinereus_s_000002.png',
#  b'turbot_s_001406.png',
#  b'bachelor_girl_s_000898.png',
#  b'bungalow_s_000445.png',
#  b'school_bus_s_000957.png',
#  b'lobster_s_001195.png',
#  b'lift_bridge_s_000096.png',
#  b'squirrel_s_001608.png',
#  b'opossum_s_001254.png',
#  b'milk_can_s_000439.png',
#  b'buckingham_palace_s_001586.png',
#  b'oriental_cockroach_s_000825.png',
#  b'dolphin_s_002246.png',
#  b'sofa_s_000373.png',
#  b'willow_tree_s_000241.png',
#  b'boardinghouse_s_000788.png',
#  b'built_in_bed_s_002088.png',
#  b'woman_s_000118.png',
#  b'indian_elephant_s_000126.png',
#  b'armoire_s_000119.png',
#  b'bed_s_000049.png',
#  b'stegosaurus_s_000500.png',
#  b'raccoon_s_000790.png',
#  b'mushroom_s_000703.png',
#  b'apis_mellifera_s_000192.png',
#  b'stingray_s_000665.png',
#  b'mus_musculus_s_000516.png',
#  b'access_road_s_001516.png',
#  b'crocodylus_porosus_s_000279.png',
#  b'poppy_s_001782.png',
#  b'dozer_s_001050.png',
#  b'built_in_bed_s_001896.png',
#  b'boy_s_000058.png',
#  b'school_bus_s_001733.png',
#  b'raccoon_s_002690.png',
#  b'river_otter_s_001146.png',
#  b'camel_s_000550.png',
#  b'poppy_s_002772.png',
#  b'sorex_araneus_s_000247.png',
#  b'elephant_s_002146.png',
#  b'sea_turtle_s_000716.png',
#  b'pine_tree_s_002529.png',
#  b'goldfish_s_002650.png',
#  b'wolf_cub_s_000001.png',
#  b'flounder_s_000775.png',
#  b'computer_keyboard_s_000890.png',
#  b'power_mower_s_000250.png',
#  b'poppy_s_001857.png',
#  b'adriatic_s_001680.png',
#  b'rose_s_000257.png',
#  b'woman_s_000060.png',
#  b'power_mower_s_001166.png',
#  b'leopard_s_000662.png',
#  b'rose_s_001882.png',
#  b'bear_cub_s_000624.png',
#  b'sweater_girl_s_000940.png',
#  b'car_train_s_000082.png',
#  b'clock_s_001539.png',
#  b'harvest_mouse_s_000194.png',
#  b'plate_iron_s_000997.png',
#  b'raccoon_s_002698.png',
#  b'tulip_s_000947.png',
#  b'valencia_orange_s_000601.png',
#  b'drawbridge_s_001664.png',
#  b'breakfast_table_s_000556.png',
#  b'forest_s_000992.png',
#  b'bosc_s_000407.png',
#  b'turtle_s_001718.png',
#  b'spider_s_001497.png',
#  b'research_rocket_s_000539.png',
#  b'navel_orange_s_000143.png',
#  b'whiskey_jug_s_000277.png',
#  b'bos_taurus_s_000619.png',
#  b'honeybee_s_000310.png',
#  b'armchair_s_001136.png',
#  b'skyscraper_s_000934.png',
#  b'built_in_bed_s_000502.png',
#  b'black_woman_s_000960.png',
#  b'tulip_s_001325.png',
#  b'hognose_snake_s_001663.png',
#  b'sea_turtle_s_002009.png',
#  b'spider_s_001779.png',
#  b'chimpanzee_s_001583.png',
#  b'mushroom_s_001276.png',
#  b'shrew_s_001906.png',
#  b'skyscraper_s_001994.png',
#  b'oil_palm_s_000454.png',
#  b'striped_skunk_s_000494.png',
#  b'crocodile_s_000909.png',
#  b'clock_s_000653.png',
#  b'bungalow_s_000196.png',
#  b'soda_can_s_000033.png',
#  b'eared_seal_s_000131.png',
#  b'tram_s_000368.png',
#  b'hamster_s_001850.png',
#  b'motorcycle_s_001119.png',
#  b'minibus_s_000262.png',
#  b'date_palm_s_000372.png',
#  b'mountain_rose_s_001226.png',
#  b'macoun_s_000009.png',
#  b'porcupine_s_001674.png',
#  b'train_s_000625.png',
#  b'orange_s_002710.png',
#  b'dinosaur_s_001534.png',
#  b'possum_s_000131.png',
#  b'baby_s_000673.png',
#  b'sweet_pepper_s_000279.png',
#  b'hedgehog_s_000556.png',
#  b'tractor_s_001028.png',
#  b'butterfly_s_000370.png',
#  b'raccoon_s_001347.png',
#  b'whale_s_002097.png',
#  b'rabbit_s_001681.png',
#  b'tank_s_000008.png',
#  b'built_in_bed_s_001227.png',
#  b'ladybug_s_001132.png',
#  b'pickup_s_000479.png',
#  b'plate_s_002308.png',
#  b'leopard_s_000757.png',
#  b'pinyon_s_000218.png',
#  b'bungalow_s_000425.png',
#  b'drawbridge_s_001656.png',
#  b'leopard_s_001301.png',
#  b'racoon_s_000787.png',
#  b'sea_s_001604.png',
#  b'lamp_s_001770.png',
#  b'porcupine_s_002259.png',
#  b'american_lobster_s_000411.png',
#  b'bos_taurus_s_000049.png',
#  b'forest_s_001125.png',
#  b'river_otter_s_000683.png',
#  b'crab_s_002122.png',
#  b'cortland_s_000650.png',
#  b'serengeti_plain_s_001066.png',
#  b'break_seal_s_000578.png',
#  b'castor_canadensis_s_001448.png',
#  b'hedgehog_s_000563.png',
#  b'twin_towers_s_001537.png',
#  b'adam_s_000356.png',
#  b'possum_s_000816.png',
#  b'salix_purpurea_s_000339.png',
#  b'intercontinental_ballistic_missile_s_000538.png',
#  b'opossum_s_001492.png',
#  b'striped_skunk_s_000497.png',
#  b'forest_s_001985.png',
#  b'syrian_hamster_s_001230.png',
#  b'stone_crab_s_000962.png',
#  b'poppy_s_000495.png',
#  b'caterpillar_s_000106.png',
#  b'moped_s_000009.png',
#  b'harvest_mouse_s_000143.png',
#  b'hamster_s_002488.png',
#  b'crab_s_002377.png',
#  b'beaker_s_000099.png',
#  b'adriatic_sea_s_000957.png',
#  b'world_trade_center_s_000306.png',
#  b'lobster_s_001370.png',
#  b'quercus_rubra_s_001209.png',
#  b'lapin_s_001094.png',
#  b'pine_tree_s_001278.png',
#  b'motor_mower_s_000124.png',
#  b'exocet_s_000806.png',
#  b'camelus_dromedarius_s_000735.png',
#  b'tv_s_002532.png',
#  b'harvest_mouse_s_000703.png',
#  b'boy_s_001243.png',
#  b'adriatic_sea_s_002040.png',
#  b'cricetus_cricetus_s_000082.png',
#  b'breakfast_table_s_000448.png',
#  b'lamna_nasus_s_000018.png',
#  b'man_s_001955.png',
#  b'sweet_pepper_s_001132.png',
#  b'lift_bridge_s_000765.png',
#  b'spider_s_000171.png',
#  b'orchid_s_000122.png',
#  b'fieldmouse_s_000086.png',
#  b'skunk_s_000783.png',
#  b'eared_seal_s_000064.png',
#  b'boardinghouse_s_001452.png',
#  b'trout_s_000575.png',
#  b'bos_taurus_s_000453.png',
#  b'sunflower_s_001383.png',
#  b'clock_s_000833.png',
#  b'lawn_mower_s_001300.png',
#  b'bitter_orange_s_000009.png',
#  b'butterfly_s_002546.png',
#  b'arabian_camel_s_000180.png',
#  b'breakfast_table_s_000095.png',
#  b'altar_boy_s_001240.png',
#  b'female_child_s_001015.png',
#  b'bell_pepper_s_000600.png',
#  b'cricetus_cricetus_s_000050.png',
#  b'castle_s_000117.png',
#  b'shrew_s_000262.png',
#  b'stone_crab_s_000049.png',
#  b'adam_s_002360.png',
#  b'wolf_cub_s_001039.png',
#  b'armoured_combat_vehicle_s_000505.png',
#  b'black_woman_s_001633.png',
#  b'bowl_s_002145.png',
#  b'hedgehog_s_001046.png',
#  b'fur_seal_s_000253.png',
#  b'turtle_s_001475.png',
#  b'american_lobster_s_000709.png',
#  b'rorqual_s_001448.png',
#  b'dual_carriageway_s_000062.png',
#  b'butterfly_s_000514.png',
#  b'poppy_s_000462.png',
#  b'shark_s_001253.png',
#  b'poppy_s_001352.png',
#  b'boy_s_002310.png',
#  b'cloud_s_001128.png',
#  b'oriental_cockroach_s_001345.png',
#  b'timber_wolf_s_000145.png',
#  b'winter_flounder_s_000509.png',
#  b'worm_snake_s_001265.png',
#  b'stegosaurus_s_000069.png',
#  b'orchid_s_000350.png',
#  b'lounge_chair_s_000495.png',
#  b'lawn_mower_s_001398.png',
#  b'tiger_s_001191.png',
#  b'red_fox_s_001285.png',
#  b'tv_s_000869.png',
#  b'poppy_s_000566.png',
#  b'stegosaurus_s_000237.png',
#  b'red_delicious_s_001702.png',
#  b'castor_fiber_s_000819.png',
#  b'elephant_s_001206.png',
#  b'house_mouse_s_000308.png',
#  b'forest_s_000440.png',
#  b'bed_s_001140.png',
#  b'ordinary_bicycle_s_000023.png',
#  b'motorcycle_s_001693.png',
#  b'adriatic_s_000580.png',
#  b'adriatic_s_001675.png',
#  b'armoire_s_000161.png',
#  b'built_in_bed_s_001048.png',
#  b'dromedary_s_001076.png',
#  b'beer_can_s_000406.png',
#  b'white_woman_s_000362.png',
#  b'stegosaurus_s_001979.png',
#  b'panthera_pardus_s_000033.png',
#  b'access_road_s_000152.png',
#  b'lamp_s_000520.png',
#  b'finback_s_000416.png',
#  b'armoured_combat_vehicle_s_000808.png',
#  b'possum_s_000042.png',
#  b'electric_lamp_s_000269.png',
#  b'cockroach_s_002075.png',
#  b'bear_cub_s_000107.png',
#  b'male_child_s_000350.png',
#  b'argiope_aurantia_s_000987.png',
#  b'bowl_s_001679.png',
#  b'bear_cub_s_001848.png',
#  b'shark_s_001001.png',
#  b'clock_s_000738.png',
#  b'chalice_s_000722.png',
#  b'rose_s_001048.png',
#  b'closet_s_002159.png',
#  b'leopard_s_000225.png',
#  b'butterfly_s_000770.png',
#  b'beaver_s_000012.png',
#  b'caterpillar_s_000910.png',
#  b'telephone_s_001949.png',
#  b'beaver_s_000091.png',
#  b'halibut_s_000356.png',
#  b'wallaby_s_000599.png',
#  b'oriental_cockroach_s_000490.png',
#  b'lapin_s_001838.png',
#  b'skunk_s_000280.png',
#  b'goldfish_s_002509.png',
#  b'tiger_beetle_s_000554.png',
#  b'worm_s_000355.png',
#  b'pickup_truck_s_001463.png',
#  b'safety_bicycle_s_001570.png',
#  b'stingray_s_001052.png',
#  b'bowl_s_000405.png',
#  b'banded_gecko_s_000045.png',
#  b'black_woman_s_001009.png',
#  b'panthera_tigris_s_000282.png',
#  b'indian_elephant_s_000666.png',
#  b'bell_pepper_s_000539.png',
#  b'hedgehog_s_000573.png',
#  b'pine_tree_s_000927.png',
#  b'red_fox_s_001529.png',
#  b'streetcar_s_000571.png',
#  b'orchid_s_001119.png',
#  b'beaker_s_000506.png',
#  b'skyscraper_s_001711.png',
#  b'table_s_001061.png',
#  b'flying_gecko_s_000181.png',
#  b'tiger_s_000288.png',
#  b'pinon_pine_s_000164.png',
#  b'rabbit_s_001085.png',
#  b'safety_bike_s_000989.png',
#  b'rainbow_trout_s_001404.png',
#  b'mushroom_s_000638.png',
#  b'leopard_s_001512.png',
#  b'cirrocumulus_s_000070.png',
#  b'chaise_s_002187.png',
#  b'dungeness_crab_s_002016.png',
#  b'garden_snail_s_000226.png',
#  b'brown_snail_s_000019.png',
#  b'beaver_s_000452.png',
#  b'table_s_002872.png',
#  b'beaver_s_000526.png',
#  b'bicycle_s_001673.png',
#  b'field_s_002490.png',
#  b'lawn_mower_s_001092.png',
#  b'willow_tree_s_002364.png',
#  ...]

# %% [markdown]
# As documented on the homepage, `b'data'` contains rows of 3073 unsigned integers, representing three channels (red, green, and blue) for one 32x32 pixel image per row.

# %%
32*32*3
# Out:
# 3072

# %% [markdown]
# For a simple gut-check, let's transform one of our images. Each 1024 items in a row is a channel (red, green, then blue). Each 32 items in the channel are a row in the 32x32 image. Using python, we can stack these channels into a 32x32x3 array, and save it as a PNG file:

# %%
import numpy as np

# Each 1024 in a row is a channel (red, green, then blue)
row = dataset_train[b'data'][0]
red, green, blue = row[0:1024], row[1024:2048], row[2048:]

# Each 32 items in the channel are a row in the 32x32 image
red = red.reshape(32,32)
green = green.reshape(32,32)
blue = blue.reshape(32,32)

# Combine the channels into a 32x32x3 image!
combined = np.dstack((red,green,blue))

# %% [markdown]
# For a more concise version, consider the following:

# %%
# All in one:
test_image = np.dstack((
    row[0:1024].reshape(32,32),
    row[1024:2048].reshape(32,32),
    row[2048:].reshape(32,32)
))

# %%
import matplotlib.pyplot as plt
plt.imshow(test_image);
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Looks like a cow! Let's check the label. `dataset_meta` contains label names in order, and `dataset_train` has a list of labels for each row.

# %%
dataset_train[b'fine_labels'][0]
# Out:
# 19

# %% [markdown]
# Our image has a label of `19`, so let's see what the 19th item is in the list of label names.

# %%
print(dataset_meta[b'fine_label_names'][19])
# Out:
# b'cattle'

# %% [markdown]
# Ok! 'cattle' sounds about right. By the way, using the previous two lines we can do:

# %%
n = 0
print(dataset_meta[b'fine_label_names'][dataset_train[b'fine_labels'][n]])
# Out:
# b'cattle'

# %% [markdown]
# Now we know how to check labels, is there a way that we can also check file names? `dataset_train` also contains a `b'filenames'` key. Let's see what we have here:

# %%
print(dataset_train[b'filenames'][0])
# Out:
# b'bos_taurus_s_000507.png'

# %% [markdown]
# "Taurus" is the name of a subspecies of cattle, so this looks like a pretty reasonable filename. To save an image we can also do:

# %%
plt.imsave("file.png", test_image)

# %% [markdown]
# Your new PNG file should now appear in the file explorer -- go ahead and pop it open to see!
#
# Now that you know how to reshape the images, save them as files, and capture their filenames and labels, let's just capture all the bicycles and motorcycles and save them. Scones Unlimited can use a model that tells these apart to route delivery drivers automatically.
#
# In the following cell, identify the label numbers for Bicycles and Motorcycles:

# %%
# creates a map from id of label to label name
id_to_name = {idx: label for idx, label in enumerate(dataset_meta[b'fine_label_names'])}

# creates a reverse map from label name to id of label
name_to_id = {label: idx for idx, label in id_to_name.items()}

# %%
import pandas as pd

# Todo: Filter the dataset_train and dataset_meta objects to find the label numbers for Bicycle and Motorcycles
bicycle_id = name_to_id[b'bicycle'] 
motorcycle_id = name_to_id[b'motorcycle']

print(bicycle_id, motorcycle_id)
# Out:
# 8 48

# %% [markdown]
# Good job! We only need objects with label 8 and 48 -- this drastically simplifies our handling of the data! Below we construct a dataframe for you, and you can safely drop the rows that don't contain observations about bicycles and motorcycles. Fill in the missing lines below to drop all other rows:

# %%
#Construct the dataframe
df_train = pd.DataFrame({
    "filenames": dataset_train[b'filenames'],
    "labels": dataset_train[b'fine_labels'],
    "row": range(len(dataset_train[b'filenames']))
})

# Drop all rows from df_train where label is not 8 or 48
df_train = df_train[df_train['labels'].isin([8, 48])]

# Decode df_train.filenames so they are regular strings
df_train["filenames"] = df_train["filenames"].apply(
    lambda x: x.decode("utf-8")
)


df_test = pd.DataFrame({
    "filenames": dataset_test[b'filenames'],
    "labels": dataset_test[b'fine_labels'],
    "row": range(len(dataset_test[b'filenames']))
})

# Drop all rows from df_test where label is not 8 or 48
df_test = df_test[df_test['labels'].isin([8, 48])]

# Decode df_test.filenames so they are regular strings
df_test["filenames"] = df_test["filenames"].apply(
    lambda x: x.decode("utf-8")
)

# %%
df_train.head()
# Out:
#                    filenames  labels  row
# 16         bike_s_000682.png       8   16
# 30         bike_s_000127.png       8   30
# 130       cycle_s_002598.png       8  130
# 152    minibike_s_000824.png      48  152
# 195  motorcycle_s_001856.png      48  195

# %%
df_test.head()
# Out:
#                          filenames  labels  row
# 27        safety_bike_s_000390.png       8   27
# 28               bike_s_000658.png       8   28
# 116        velocipede_s_001744.png       8  116
# 161              bike_s_000643.png       8  161
# 319  ordinary_bicycle_s_000437.png       8  319

# %% [markdown]
# Now that the data is filtered for just our classes, we can save all our images.

# %%
# !mkdir ./train
# !mkdir ./test

# %% [markdown]
# In the previous sections we introduced you to several key snippets of code:
#
# 1. Grabbing the image data:
#
# ```python
# dataset_train[b'data'][0]
# ```
#
# 2. A simple idiom for stacking the image data into the right shape
#
# ```python
# import numpy as np
# np.dstack((
#     row[0:1024].reshape(32,32),
#     row[1024:2048].reshape(32,32),
#     row[2048:].reshape(32,32)
# ))
# ```
#
# 3. A simple `matplotlib` utility for saving images
#
# ```python
# plt.imsave(path+row['filenames'], target)
# ```
#
# Compose these together into a function that saves all the images into the `./test` and `./train` directories. Use the comments in the body of the `save_images` function below to guide your construction of the function:

# %%
def save_images():
    for i in range(len(df_train['filenames'])):
        #Grab the image data in row-major form
        img = dataset_train[b'data'][df_train['row'].iloc[i]]
        
        # Consolidated stacking/reshaping from earlier
        target = np.dstack((
            img[0:1024].reshape(32, 32),
            img[1024:2048].reshape(32, 32),
            img[2048:].reshape(32, 32)
        ))
        
        # Save the image
        plt.imsave(f"./train/{df_train['filenames'].iloc[i]}", target)

    for i in range(len(df_test['filenames'])):
        img = dataset_test[b'data'][df_test['row'].iloc[i]]

        target = np.dstack((
            img[0:1024].reshape(32, 32),
            img[1024:2048].reshape(32, 32),
            img[2048:].reshape(32, 32)
        ))

        plt.imsave(f"./test/{df_test['filenames'].iloc[i]}", target)
            
    return "All images saved."

## TODO: save ALL images using the save_images function
save_images()
# Out:
# 'All images saved.'

# %% [markdown]
# ### 3. Load the data
#
# Now we can load the data into S3.
#
# Using the sagemaker SDK grab the current region, execution role, and bucket.

# %%
import sagemaker

session = sagemaker.session.Session()

bucket = session.default_bucket()
print("Default Bucket: {}".format(bucket))

region = session.boto_region_name
print("AWS Region: {}".format(region))

role = sagemaker.get_execution_role()
print("RoleArn: {}".format(role))
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pydantic/_internal/_fields.py:198: UserWarning: Field name "json" in "MonitoringDatasetFormat" shadows an attribute in parent "Base"
#   warnings.warn(
# [04/14/25 09:58:47] INFO     Found credentials from IAM Role:                                   ]8;id=755912;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=421042;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# [04/14/25 09:58:51] INFO     Found credentials from IAM Role:                                   ]8;id=37229;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=637954;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# Default Bucket: sagemaker-us-east-1-465430730249
# AWS Region: us-east-1
# [04/14/25 09:58:52] INFO     Found credentials from IAM Role:                                   ]8;id=733240;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=92953;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# RoleArn: arn:aws:iam::465430730249:role/service-role/AmazonSageMaker-ExecutionRole-20250412T164216

# %% [markdown]
# With this data we can easily sync your data up into S3!

# %%
import os

os.environ["DEFAULT_S3_BUCKET"] = bucket
# !aws s3 sync ./train s3://${DEFAULT_S3_BUCKET}/train/
# !aws s3 sync ./test s3://${DEFAULT_S3_BUCKET}/test/
# Out:
# upload: train/bicycle_s_000017.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000017.png
# upload: train/bicycle_s_000039.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000039.png
# upload: train/bicycle_s_000035.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000035.png
# upload: train/bicycle_s_000071.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000071.png
# upload: train/bicycle_s_000038.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000038.png
# upload: train/bicycle_s_000021.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000021.png
# upload: train/bicycle_s_000231.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000231.png
# upload: train/bicycle_s_000124.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000124.png
# upload: train/bicycle_s_000137.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000137.png
# upload: train/bicycle_s_000159.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000159.png
# upload: train/bicycle_s_000279.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000279.png
# upload: train/bicycle_s_000051.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000051.png
# upload: train/bicycle_s_000282.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000282.png
# upload: train/bicycle_s_000314.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000314.png
# upload: train/bicycle_s_000371.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000371.png
# upload: train/bicycle_s_000243.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000243.png
# upload: train/bicycle_s_000392.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000392.png
# upload: train/bicycle_s_000099.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000099.png
# upload: train/bicycle_s_000396.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000396.png
# upload: train/bicycle_s_000156.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000156.png
# upload: train/bicycle_s_000435.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000435.png
# upload: train/bicycle_s_000043.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000043.png
# upload: train/bicycle_s_000408.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000408.png
# upload: train/bicycle_s_000066.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000066.png
# upload: train/bicycle_s_000147.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000147.png
# upload: train/bicycle_s_000399.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000399.png
# upload: train/bicycle_s_000149.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000149.png
# upload: train/bicycle_s_000235.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000235.png
# upload: train/bicycle_s_000369.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000369.png
# upload: train/bicycle_s_000491.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000491.png
# upload: train/bicycle_s_000463.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000463.png
# upload: train/bicycle_s_000437.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000437.png
# upload: train/bicycle_s_000536.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000536.png
# upload: train/bicycle_s_000467.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000467.png
# upload: train/bicycle_s_000522.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000522.png
# upload: train/bicycle_s_000537.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000537.png
# upload: train/bicycle_s_000180.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000180.png
# upload: train/bicycle_s_000546.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000546.png
# upload: train/bicycle_s_000569.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000569.png
# upload: train/bicycle_s_000668.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000668.png
# upload: train/bicycle_s_000723.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000723.png
# upload: train/bicycle_s_000774.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000774.png
# upload: train/bicycle_s_000667.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000667.png
# upload: train/bicycle_s_000775.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000775.png
# upload: train/bicycle_s_000561.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000561.png
# upload: train/bicycle_s_000759.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000759.png
# upload: train/bicycle_s_000753.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000753.png
# upload: train/bicycle_s_000778.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000778.png
# upload: train/bicycle_s_000781.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000781.png
# upload: train/bicycle_s_000829.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000829.png
# upload: train/bicycle_s_000782.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000782.png
# upload: train/bicycle_s_000861.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000861.png
# upload: train/bicycle_s_000986.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000986.png
# upload: train/bicycle_s_000978.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000978.png
# upload: train/bicycle_s_000822.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000822.png
# upload: train/bicycle_s_000951.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000951.png
# upload: train/bicycle_s_000996.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000996.png
# upload: train/bicycle_s_001002.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001002.png
# upload: train/bicycle_s_001228.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001228.png
# upload: train/bicycle_s_000785.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_000785.png
# upload: train/bicycle_s_001245.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001245.png
# upload: train/bicycle_s_001205.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001205.png
# upload: train/bicycle_s_001168.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001168.png
# upload: train/bicycle_s_001338.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001338.png
# upload: train/bicycle_s_001203.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001203.png
# upload: train/bicycle_s_001111.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001111.png
# upload: train/bicycle_s_001247.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001247.png
# upload: train/bicycle_s_001174.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001174.png
# upload: train/bicycle_s_001388.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001388.png
# upload: train/bicycle_s_001409.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001409.png
# upload: train/bicycle_s_001348.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001348.png
# upload: train/bicycle_s_001402.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001402.png
# upload: train/bicycle_s_001452.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001452.png
# upload: train/bicycle_s_001554.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001554.png
# upload: train/bicycle_s_001642.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001642.png
# upload: train/bicycle_s_001448.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001448.png
# upload: train/bicycle_s_001569.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001569.png
# upload: train/bicycle_s_001470.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001470.png
# upload: train/bicycle_s_001411.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001411.png
# upload: train/bicycle_s_001583.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001583.png
# upload: train/bicycle_s_001663.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001663.png
# upload: train/bicycle_s_001748.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001748.png
# upload: train/bicycle_s_001688.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001688.png
# upload: train/bicycle_s_001757.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001757.png
# upload: train/bicycle_s_001673.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001673.png
# upload: train/bicycle_s_001814.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001814.png
# upload: train/bicycle_s_001687.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001687.png
# upload: train/bicycle_s_001693.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001693.png
# upload: train/bicycle_s_001904.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001904.png
# upload: train/bicycle_s_001679.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001679.png
# upload: train/bicycle_s_001681.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001681.png
# upload: train/bicycle_s_001928.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001928.png
# upload: train/bicycle_s_002029.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002029.png
# upload: train/bicycle_s_002132.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002132.png
# upload: train/bicycle_s_002100.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002100.png
# upload: train/bicycle_s_002005.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002005.png
# upload: train/bicycle_s_002129.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002129.png
# upload: train/bicycle_s_002049.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002049.png
# upload: train/bicycle_s_002012.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002012.png
# upload: train/bicycle_s_002153.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002153.png
# upload: train/bicycle_s_002258.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002258.png
# upload: train/bicycle_s_002247.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002247.png
# upload: train/bicycle_s_002222.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002222.png
# upload: train/bicycle_s_002218.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002218.png
# upload: train/bicycle_s_002338.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002338.png
# upload: train/bicycle_s_002373.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002373.png
# upload: train/bicycle_s_002237.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002237.png
# upload: train/bicycle_s_002374.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002374.png
# upload: train/bicycle_s_001956.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_001956.png
# upload: train/bicycle_s_002299.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002299.png
# upload: train/bicycle_s_002436.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002436.png
# upload: train/bicycle_s_002410.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002410.png
# upload: train/bicycle_s_002400.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002400.png
# upload: train/bicycle_s_002448.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002448.png
# upload: train/bicycle_s_002521.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002521.png
# upload: train/bicycle_s_002475.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002475.png
# upload: train/bicycle_s_002569.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002569.png
# upload: train/bicycle_s_002550.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002550.png
# upload: train/bicycle_s_002711.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002711.png
# upload: train/bicycle_s_002715.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002715.png
# upload: train/bicycle_s_002624.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002624.png
# upload: train/bicycle_s_002725.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002725.png
# upload: train/bicycle_s_002661.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002661.png
# upload: train/bicycle_s_002669.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002669.png
# upload: train/bicycle_s_002728.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002728.png
# upload: train/bicycle_s_002729.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002729.png
# upload: train/bike_s_000005.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000005.png
# upload: train/bike_s_000003.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000003.png
# upload: train/bike_s_000015.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000015.png
# upload: train/bike_s_000018.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000018.png
# upload: train/bike_s_000021.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000021.png
# upload: train/bicycle_s_002762.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002762.png
# upload: train/bicycle_s_002759.png to s3://sagemaker-us-east-1-465430730249/train/bicycle_s_002759.png
# upload: train/bike_s_000001.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000001.png
# upload: train/bike_s_000023.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000023.png
# upload: train/bike_s_000034.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000034.png
# upload: train/bike_s_000025.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000025.png
# upload: train/bike_s_000035.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000035.png
# upload: train/bike_s_000026.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000026.png
# upload: train/bike_s_000024.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000024.png
# upload: train/bike_s_000111.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000111.png
# upload: train/bike_s_000040.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000040.png
# upload: train/bike_s_000062.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000062.png
# upload: train/bike_s_000051.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000051.png
# upload: train/bike_s_000121.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000121.png
# upload: train/bike_s_000162.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000162.png
# upload: train/bike_s_000127.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000127.png
# upload: train/bike_s_000164.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000164.png
# upload: train/bike_s_000237.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000237.png
# upload: train/bike_s_000204.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000204.png
# upload: train/bike_s_000129.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000129.png
# upload: train/bike_s_000256.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000256.png
# upload: train/bike_s_000302.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000302.png
# upload: train/bike_s_000154.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000154.png
# upload: train/bike_s_000299.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000299.png
# upload: train/bike_s_000304.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000304.png
# upload: train/bike_s_000392.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000392.png
# upload: train/bike_s_000364.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000364.png
# upload: train/bike_s_000336.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000336.png
# upload: train/bike_s_000390.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000390.png
# upload: train/bike_s_000544.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000544.png
# upload: train/bike_s_000516.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000516.png
# upload: train/bike_s_000397.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000397.png
# upload: train/bike_s_000506.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000506.png
# upload: train/bike_s_000474.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000474.png
# upload: train/bike_s_000522.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000522.png
# upload: train/bike_s_000545.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000545.png
# upload: train/bike_s_000679.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000679.png
# upload: train/bike_s_000682.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000682.png
# upload: train/bike_s_000657.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000657.png
# upload: train/bike_s_000926.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000926.png
# upload: train/bike_s_000628.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000628.png
# upload: train/bike_s_000855.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000855.png
# upload: train/bike_s_000593.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000593.png
# upload: train/bike_s_000722.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000722.png
# upload: train/bike_s_000555.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000555.png
# upload: train/bike_s_000934.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000934.png
# upload: train/bike_s_000990.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_000990.png
# upload: train/bike_s_001072.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001072.png
# upload: train/bike_s_001131.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001131.png
# upload: train/bike_s_001113.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001113.png
# upload: train/bike_s_001116.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001116.png
# upload: train/bike_s_001093.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001093.png
# upload: train/bike_s_001027.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001027.png
# upload: train/bike_s_001200.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001200.png
# upload: train/bike_s_001260.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001260.png
# upload: train/bike_s_001078.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001078.png
# upload: train/bike_s_001380.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001380.png
# upload: train/bike_s_001320.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001320.png
# upload: train/bike_s_001226.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001226.png
# upload: train/bike_s_001418.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001418.png
# upload: train/bike_s_001375.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001375.png
# upload: train/bike_s_001414.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001414.png
# upload: train/bike_s_001415.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001415.png
# upload: train/bike_s_001572.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001572.png
# upload: train/bike_s_001739.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001739.png
# upload: train/bike_s_001462.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001462.png
# upload: train/bike_s_001592.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001592.png
# upload: train/bike_s_001519.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001519.png
# upload: train/bike_s_001679.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001679.png
# upload: train/bike_s_001613.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001613.png
# upload: train/bike_s_001683.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001683.png
# upload: train/bike_s_001517.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001517.png
# upload: train/bike_s_001761.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001761.png
# upload: train/bike_s_001827.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001827.png
# upload: train/bike_s_001915.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001915.png
# upload: train/bike_s_001882.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001882.png
# upload: train/bike_s_001876.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001876.png
# upload: train/bike_s_001847.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001847.png
# upload: train/bike_s_001839.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001839.png
# upload: train/bike_s_001877.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001877.png
# upload: train/bike_s_001928.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001928.png
# upload: train/bike_s_001767.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001767.png
# upload: train/bike_s_001897.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001897.png
# upload: train/bike_s_001945.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001945.png
# upload: train/bike_s_002024.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002024.png
# upload: train/bike_s_002033.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002033.png
# upload: train/bike_s_002090.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002090.png
# upload: train/bike_s_002047.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002047.png
# upload: train/bike_s_002042.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002042.png
# upload: train/bike_s_001980.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_001980.png
# upload: train/bike_s_002098.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002098.png
# upload: train/bike_s_002118.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002118.png
# upload: train/bike_s_002109.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002109.png
# upload: train/bike_s_002164.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002164.png
# upload: train/bike_s_002139.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002139.png
# upload: train/bike_s_002203.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002203.png
# upload: train/bike_s_002215.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002215.png
# upload: train/bike_s_002277.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002277.png
# upload: train/bike_s_002222.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002222.png
# upload: train/bike_s_002283.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002283.png
# upload: train/cycle_s_000042.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_000042.png
# upload: train/bike_s_002288.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002288.png
# upload: train/cycle_s_000222.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_000222.png
# upload: train/bike_s_002292.png to s3://sagemaker-us-east-1-465430730249/train/bike_s_002292.png
# upload: train/cycle_s_000583.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_000583.png
# upload: train/cycle_s_000318.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_000318.png
# upload: train/cycle_s_000639.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_000639.png
# upload: train/cycle_s_000718.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_000718.png
# upload: train/cycle_s_000492.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_000492.png
# upload: train/cycle_s_000463.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_000463.png
# upload: train/cycle_s_000871.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_000871.png
# upload: train/cycle_s_000666.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_000666.png
# upload: train/cycle_s_000899.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_000899.png
# upload: train/cycle_s_001413.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001413.png
# upload: train/cycle_s_001286.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001286.png
# upload: train/cycle_s_001472.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001472.png
# upload: train/cycle_s_001439.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001439.png
# upload: train/cycle_s_001477.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001477.png
# upload: train/cycle_s_001640.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001640.png
# upload: train/cycle_s_001309.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001309.png
# upload: train/cycle_s_001474.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001474.png
# upload: train/cycle_s_001412.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001412.png
# upload: train/cycle_s_001374.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001374.png
# upload: train/cycle_s_002015.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002015.png
# upload: train/cycle_s_001735.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001735.png
# upload: train/cycle_s_001875.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001875.png
# upload: train/cycle_s_001745.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001745.png
# upload: train/cycle_s_002053.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002053.png
# upload: train/cycle_s_001976.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_001976.png
# upload: train/cycle_s_002092.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002092.png
# upload: train/cycle_s_002090.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002090.png
# upload: train/cycle_s_002503.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002503.png
# upload: train/cycle_s_002168.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002168.png
# upload: train/cycle_s_002638.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002638.png
# upload: train/cycle_s_002598.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002598.png
# upload: train/cycle_s_002178.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002178.png
# upload: train/cycle_s_002651.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002651.png
# upload: train/cycle_s_002093.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002093.png
# upload: train/cycle_s_002399.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002399.png
# upload: train/cycle_s_002659.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002659.png
# upload: train/cycle_s_002666.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002666.png
# upload: train/cycle_s_002844.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002844.png
# upload: train/cycle_s_002904.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002904.png
# upload: train/cycle_s_002703.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002703.png
# upload: train/cycle_s_002746.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002746.png
# upload: train/cycle_s_003006.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_003006.png
# upload: train/cycle_s_002978.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002978.png
# upload: train/cycle_s_002882.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002882.png
# upload: train/cycle_s_002779.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_002779.png
# upload: train/cycle_s_003008.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_003008.png
# upload: train/cycle_s_003026.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_003026.png
# upload: train/cycle_s_003147.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_003147.png
# upload: train/cycle_s_003122.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_003122.png
# upload: train/dirt_bike_s_000003.png to s3://sagemaker-us-east-1-465430730249/train/dirt_bike_s_000003.png
# upload: train/cycle_s_003043.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_003043.png
# upload: train/dirt_bike_s_000005.png to s3://sagemaker-us-east-1-465430730249/train/dirt_bike_s_000005.png
# upload: train/cycle_s_003148.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_003148.png
# upload: train/cycle_s_003162.png to s3://sagemaker-us-east-1-465430730249/train/cycle_s_003162.png
# upload: train/dirt_bike_s_000017.png to s3://sagemaker-us-east-1-465430730249/train/dirt_bike_s_000017.png
# upload: train/dirt_bike_s_000030.png to s3://sagemaker-us-east-1-465430730249/train/dirt_bike_s_000030.png
# upload: train/dirt_bike_s_000059.png to s3://sagemaker-us-east-1-465430730249/train/dirt_bike_s_000059.png
# upload: train/dirt_bike_s_000124.png to s3://sagemaker-us-east-1-465430730249/train/dirt_bike_s_000124.png
# upload: train/minibike_s_000011.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000011.png
# upload: train/minibike_s_000010.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000010.png
# upload: train/minibike_s_000020.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000020.png
# upload: train/dirt_bike_s_000119.png to s3://sagemaker-us-east-1-465430730249/train/dirt_bike_s_000119.png
# upload: train/minibike_s_000035.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000035.png
# upload: train/minibike_s_000022.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000022.png
# upload: train/dirt_bike_s_000134.png to s3://sagemaker-us-east-1-465430730249/train/dirt_bike_s_000134.png
# upload: train/minibike_s_000036.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000036.png
# upload: train/minibike_s_000108.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000108.png
# upload: train/minibike_s_000064.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000064.png
# upload: train/minibike_s_000121.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000121.png
# upload: train/minibike_s_000117.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000117.png
# upload: train/minibike_s_000102.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000102.png
# upload: train/minibike_s_000099.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000099.png
# upload: train/minibike_s_000116.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000116.png
# upload: train/minibike_s_000110.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000110.png
# upload: train/minibike_s_000203.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000203.png
# upload: train/minibike_s_000130.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000130.png
# upload: train/minibike_s_000146.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000146.png
# upload: train/minibike_s_000165.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000165.png
# upload: train/minibike_s_000218.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000218.png
# upload: train/minibike_s_000127.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000127.png
# upload: train/minibike_s_000314.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000314.png
# upload: train/minibike_s_000149.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000149.png
# upload: train/minibike_s_000244.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000244.png
# upload: train/minibike_s_000293.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000293.png
# upload: train/minibike_s_000340.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000340.png
# upload: train/minibike_s_000324.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000324.png
# upload: train/minibike_s_000335.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000335.png
# upload: train/minibike_s_000402.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000402.png
# upload: train/minibike_s_000409.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000409.png
# upload: train/minibike_s_000401.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000401.png
# upload: train/minibike_s_000392.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000392.png
# upload: train/minibike_s_000408.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000408.png
# upload: train/minibike_s_000362.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000362.png
# upload: train/minibike_s_000350.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000350.png
# upload: train/minibike_s_000427.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000427.png
# upload: train/minibike_s_000429.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000429.png
# upload: train/minibike_s_000451.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000451.png
# upload: train/minibike_s_000485.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000485.png
# upload: train/minibike_s_000491.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000491.png
# upload: train/minibike_s_000507.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000507.png
# upload: train/minibike_s_000434.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000434.png
# upload: train/minibike_s_000459.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000459.png
# upload: train/minibike_s_000435.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000435.png
# upload: train/minibike_s_000498.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000498.png
# upload: train/minibike_s_000518.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000518.png
# upload: train/minibike_s_000519.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000519.png
# upload: train/minibike_s_000522.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000522.png
# upload: train/minibike_s_000520.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000520.png
# upload: train/minibike_s_000511.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000511.png
# upload: train/minibike_s_000527.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000527.png
# upload: train/minibike_s_000567.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000567.png
# upload: train/minibike_s_000565.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000565.png
# upload: train/minibike_s_000566.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000566.png
# upload: train/minibike_s_000569.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000569.png
# upload: train/minibike_s_000652.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000652.png
# upload: train/minibike_s_000654.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000654.png
# upload: train/minibike_s_000570.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000570.png
# upload: train/minibike_s_000526.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000526.png
# upload: train/minibike_s_000568.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000568.png
# upload: train/minibike_s_000613.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000613.png
# upload: train/minibike_s_000698.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000698.png
# upload: train/minibike_s_000690.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000690.png
# upload: train/minibike_s_000571.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000571.png
# upload: train/minibike_s_000701.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000701.png
# upload: train/minibike_s_000743.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000743.png
# upload: train/minibike_s_000738.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000738.png
# upload: train/minibike_s_000709.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000709.png
# upload: train/minibike_s_000820.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000820.png
# upload: train/minibike_s_000824.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000824.png
# upload: train/minibike_s_000741.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000741.png
# upload: train/minibike_s_000813.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000813.png
# upload: train/minibike_s_000800.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000800.png
# upload: train/minibike_s_000802.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000802.png
# upload: train/minibike_s_000885.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000885.png
# upload: train/minibike_s_000968.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000968.png
# upload: train/minibike_s_000886.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000886.png
# upload: train/minibike_s_000914.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000914.png
# upload: train/minibike_s_000830.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000830.png
# upload: train/minibike_s_001016.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001016.png
# upload: train/minibike_s_000855.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000855.png
# upload: train/minibike_s_000967.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000967.png
# upload: train/minibike_s_000906.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000906.png
# upload: train/minibike_s_000831.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_000831.png
# upload: train/minibike_s_001079.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001079.png
# upload: train/minibike_s_001094.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001094.png
# upload: train/minibike_s_001072.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001072.png
# upload: train/minibike_s_001157.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001157.png
# upload: train/minibike_s_001179.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001179.png
# upload: train/minibike_s_001017.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001017.png
# upload: train/minibike_s_001177.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001177.png
# upload: train/minibike_s_001185.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001185.png
# upload: train/minibike_s_001168.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001168.png
# upload: train/minibike_s_001193.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001193.png
# upload: train/minibike_s_001250.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001250.png
# upload: train/minibike_s_001169.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001169.png
# upload: train/minibike_s_001261.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001261.png
# upload: train/minibike_s_001270.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001270.png
# upload: train/minibike_s_001279.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001279.png
# upload: train/minibike_s_001275.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001275.png
# upload: train/minibike_s_001294.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001294.png
# upload: train/minibike_s_001191.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001191.png
# upload: train/minibike_s_001249.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001249.png
# upload: train/minibike_s_001417.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001417.png
# upload: train/minibike_s_001344.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001344.png
# upload: train/minibike_s_001345.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001345.png
# upload: train/minibike_s_001348.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001348.png
# upload: train/minibike_s_001366.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001366.png
# upload: train/minibike_s_001458.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001458.png
# upload: train/minibike_s_001450.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001450.png
# upload: train/minibike_s_001539.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001539.png
# upload: train/minibike_s_001512.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001512.png
# upload: train/minibike_s_001479.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001479.png
# upload: train/minibike_s_001546.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001546.png
# upload: train/minibike_s_001498.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001498.png
# upload: train/minibike_s_001496.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001496.png
# upload: train/minibike_s_001511.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001511.png
# upload: train/minibike_s_001491.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001491.png
# upload: train/minibike_s_001506.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001506.png
# upload: train/minibike_s_001540.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001540.png
# upload: train/minibike_s_001558.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001558.png
# upload: train/minibike_s_001573.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001573.png
# upload: train/minibike_s_001565.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001565.png
# upload: train/minibike_s_001638.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001638.png
# upload: train/minibike_s_001689.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001689.png
# upload: train/minibike_s_001597.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001597.png
# upload: train/minibike_s_001631.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001631.png
# upload: train/minibike_s_001575.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001575.png
# upload: train/minibike_s_001639.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001639.png
# upload: train/minibike_s_001653.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001653.png
# upload: train/minibike_s_001701.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001701.png
# upload: train/minibike_s_001691.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001691.png
# upload: train/minibike_s_001747.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001747.png
# upload: train/minibike_s_001789.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001789.png
# upload: train/minibike_s_001771.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001771.png
# upload: train/minibike_s_001767.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001767.png
# upload: train/minibike_s_001731.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001731.png
# upload: train/minibike_s_001827.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001827.png
# upload: train/minibike_s_001829.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001829.png
# upload: train/minibike_s_001734.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001734.png
# upload: train/minibike_s_001836.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001836.png
# upload: train/minibike_s_001880.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001880.png
# upload: train/minibike_s_001863.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001863.png
# upload: train/minibike_s_001881.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001881.png
# upload: train/minibike_s_001838.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001838.png
# upload: train/minibike_s_001873.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001873.png
# upload: train/minibike_s_001865.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001865.png
# upload: train/minibike_s_001885.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001885.png
# upload: train/minibike_s_001870.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001870.png
# upload: train/minibike_s_001921.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001921.png
# upload: train/minibike_s_001944.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001944.png
# upload: train/minibike_s_002046.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002046.png
# upload: train/minibike_s_001996.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001996.png
# upload: train/minibike_s_002030.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002030.png
# upload: train/minibike_s_002009.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002009.png
# upload: train/minibike_s_001917.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001917.png
# upload: train/minibike_s_001972.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001972.png
# upload: train/minibike_s_002048.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002048.png
# upload: train/minibike_s_001969.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_001969.png
# upload: train/minibike_s_002038.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002038.png
# upload: train/minibike_s_002137.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002137.png
# upload: train/minibike_s_002130.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002130.png
# upload: train/minibike_s_002146.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002146.png
# upload: train/minibike_s_002124.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002124.png
# upload: train/minibike_s_002176.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002176.png
# upload: train/minibike_s_002182.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002182.png
# upload: train/minibike_s_002115.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002115.png
# upload: train/minibike_s_002186.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002186.png
# upload: train/minibike_s_002084.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002084.png
# upload: train/minibike_s_002163.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002163.png
# upload: train/moped_s_000021.png to s3://sagemaker-us-east-1-465430730249/train/moped_s_000021.png
# upload: train/minibike_s_002194.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002194.png
# upload: train/minibike_s_002198.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002198.png
# upload: train/minibike_s_002218.png to s3://sagemaker-us-east-1-465430730249/train/minibike_s_002218.png
# upload: train/moped_s_000004.png to s3://sagemaker-us-east-1-465430730249/train/moped_s_000004.png
# upload: train/moped_s_000035.png to s3://sagemaker-us-east-1-465430730249/train/moped_s_000035.png
# ...
# upload: test/cycle_s_002661.png to s3://sagemaker-us-east-1-465430730249/test/cycle_s_002661.png
# upload: test/dirt_bike_s_000001.png to s3://sagemaker-us-east-1-465430730249/test/dirt_bike_s_000001.png
# upload: test/cycle_s_001953.png to s3://sagemaker-us-east-1-465430730249/test/cycle_s_001953.png
# upload: test/minibike_s_000254.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000254.png
# upload: test/minibike_s_000290.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000290.png
# upload: test/minibike_s_000075.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000075.png
# upload: test/minibike_s_000309.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000309.png
# upload: test/minibike_s_000055.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000055.png
# upload: test/minibike_s_000052.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000052.png
# upload: test/minibike_s_000288.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000288.png
# upload: test/minibike_s_000505.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000505.png
# upload: test/minibike_s_000497.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000497.png
# upload: test/minibike_s_000828.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000828.png
# upload: test/minibike_s_000880.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000880.png
# upload: test/minibike_s_000792.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000792.png
# upload: test/minibike_s_000801.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000801.png
# upload: test/minibike_s_000913.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000913.png
# upload: test/minibike_s_000573.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000573.png
# upload: test/minibike_s_000398.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000398.png
# upload: test/cycle_s_002305.png to s3://sagemaker-us-east-1-465430730249/test/cycle_s_002305.png
# upload: test/minibike_s_001089.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_001089.png
# upload: test/minibike_s_001605.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_001605.png
# upload: test/minibike_s_001441.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_001441.png
# upload: test/minibike_s_001473.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_001473.png
# upload: test/minibike_s_001651.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_001651.png
# upload: test/minibike_s_000947.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000947.png
# upload: test/minibike_s_001732.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_001732.png
# upload: test/minibike_s_001547.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_001547.png
# upload: test/minibike_s_000960.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_000960.png
# upload: test/minibike_s_001893.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_001893.png
# upload: test/minibike_s_001867.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_001867.png
# upload: test/moped_s_000033.png to s3://sagemaker-us-east-1-465430730249/test/moped_s_000033.png
# upload: test/minibike_s_002230.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_002230.png
# upload: test/minibike_s_002051.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_002051.png
# upload: test/moped_s_000306.png to s3://sagemaker-us-east-1-465430730249/test/moped_s_000306.png
# upload: test/minibike_s_002227.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_002227.png
# upload: test/moped_s_000007.png to s3://sagemaker-us-east-1-465430730249/test/moped_s_000007.png
# upload: test/minibike_s_002173.png to s3://sagemaker-us-east-1-465430730249/test/minibike_s_002173.png
# upload: test/motorbike_s_000005.png to s3://sagemaker-us-east-1-465430730249/test/motorbike_s_000005.png
# upload: test/moped_s_000064.png to s3://sagemaker-us-east-1-465430730249/test/moped_s_000064.png
# upload: test/motorbike_s_000121.png to s3://sagemaker-us-east-1-465430730249/test/motorbike_s_000121.png
# upload: test/motorbike_s_000135.png to s3://sagemaker-us-east-1-465430730249/test/motorbike_s_000135.png
# upload: test/motorbike_s_000324.png to s3://sagemaker-us-east-1-465430730249/test/motorbike_s_000324.png
# upload: test/motorbike_s_000333.png to s3://sagemaker-us-east-1-465430730249/test/motorbike_s_000333.png
# upload: test/motorbike_s_000433.png to s3://sagemaker-us-east-1-465430730249/test/motorbike_s_000433.png
# upload: test/motorbike_s_000465.png to s3://sagemaker-us-east-1-465430730249/test/motorbike_s_000465.png
# upload: test/motorbike_s_000126.png to s3://sagemaker-us-east-1-465430730249/test/motorbike_s_000126.png
# upload: test/motorbike_s_000629.png to s3://sagemaker-us-east-1-465430730249/test/motorbike_s_000629.png
# upload: test/motorcycle_s_000049.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000049.png
# upload: test/motorcycle_s_000007.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000007.png
# upload: test/motorcycle_s_000063.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000063.png
# upload: test/motorcycle_s_000141.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000141.png
# upload: test/motorcycle_s_000042.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000042.png
# upload: test/motorcycle_s_000139.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000139.png
# upload: test/motorcycle_s_000040.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000040.png
# upload: test/motorcycle_s_000060.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000060.png
# upload: test/motorcycle_s_000171.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000171.png
# upload: test/motorcycle_s_000222.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000222.png
# upload: test/motorcycle_s_000211.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000211.png
# upload: test/motorcycle_s_000352.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000352.png
# upload: test/motorcycle_s_000323.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000323.png
# upload: test/motorcycle_s_000446.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000446.png
# upload: test/motorcycle_s_000427.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000427.png
# upload: test/motorcycle_s_000602.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000602.png
# upload: test/motorcycle_s_000530.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000530.png
# upload: test/motorcycle_s_000450.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000450.png
# upload: test/motorcycle_s_000606.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000606.png
# upload: test/motorcycle_s_000615.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000615.png
# upload: test/motorcycle_s_000512.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000512.png
# upload: test/motorcycle_s_000485.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000485.png
# upload: test/motorcycle_s_000494.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000494.png
# upload: test/motorcycle_s_000679.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000679.png
# upload: test/motorcycle_s_000866.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000866.png
# upload: test/motorcycle_s_000963.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000963.png
# upload: test/motorcycle_s_001164.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001164.png
# upload: test/motorcycle_s_000685.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000685.png
# upload: test/motorcycle_s_000739.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000739.png
# upload: test/motorcycle_s_000878.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000878.png
# upload: test/motorcycle_s_000876.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000876.png
# upload: test/motorcycle_s_000797.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000797.png
# upload: test/motorcycle_s_000825.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_000825.png
# upload: test/motorcycle_s_001519.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001519.png
# upload: test/motorcycle_s_001385.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001385.png
# upload: test/motorcycle_s_001508.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001508.png
# upload: test/motorcycle_s_001687.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001687.png
# upload: test/motorcycle_s_001261.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001261.png
# upload: test/motorcycle_s_001269.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001269.png
# upload: test/motorcycle_s_001679.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001679.png
# upload: test/motorcycle_s_001249.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001249.png
# upload: test/motorcycle_s_001782.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001782.png
# upload: test/motorcycle_s_001348.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001348.png
# upload: test/motorcycle_s_001906.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001906.png
# upload: test/motorcycle_s_002026.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_002026.png
# upload: test/motorcycle_s_001955.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001955.png
# upload: test/motorcycle_s_001936.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001936.png
# upload: test/motorcycle_s_001960.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001960.png
# upload: test/motorcycle_s_001971.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001971.png
# upload: test/motorcycle_s_001892.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_001892.png
# upload: test/ordinary_bicycle_s_000105.png to s3://sagemaker-us-east-1-465430730249/test/ordinary_bicycle_s_000105.png
# upload: test/motorcycle_s_002126.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_002126.png
# upload: test/motorcycle_s_002112.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_002112.png
# upload: test/ordinary_bicycle_s_000113.png to s3://sagemaker-us-east-1-465430730249/test/ordinary_bicycle_s_000113.png
# upload: test/ordinary_bicycle_s_000284.png to s3://sagemaker-us-east-1-465430730249/test/ordinary_bicycle_s_000284.png
# upload: test/ordinary_bicycle_s_000350.png to s3://sagemaker-us-east-1-465430730249/test/ordinary_bicycle_s_000350.png
# upload: test/ordinary_bicycle_s_000158.png to s3://sagemaker-us-east-1-465430730249/test/ordinary_bicycle_s_000158.png
# upload: test/ordinary_bicycle_s_000437.png to s3://sagemaker-us-east-1-465430730249/test/ordinary_bicycle_s_000437.png
# upload: test/ordinary_bicycle_s_000169.png to s3://sagemaker-us-east-1-465430730249/test/ordinary_bicycle_s_000169.png
# upload: test/safety_bicycle_s_000235.png to s3://sagemaker-us-east-1-465430730249/test/safety_bicycle_s_000235.png
# upload: test/ordinary_bicycle_s_000431.png to s3://sagemaker-us-east-1-465430730249/test/ordinary_bicycle_s_000431.png
# upload: test/motorcycle_s_002177.png to s3://sagemaker-us-east-1-465430730249/test/motorcycle_s_002177.png
# upload: test/safety_bicycle_s_000315.png to s3://sagemaker-us-east-1-465430730249/test/safety_bicycle_s_000315.png
# upload: test/safety_bike_s_000192.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_000192.png
# upload: test/safety_bicycle_s_001322.png to s3://sagemaker-us-east-1-465430730249/test/safety_bicycle_s_001322.png
# upload: test/safety_bicycle_s_001575.png to s3://sagemaker-us-east-1-465430730249/test/safety_bicycle_s_001575.png
# upload: test/safety_bicycle_s_001153.png to s3://sagemaker-us-east-1-465430730249/test/safety_bicycle_s_001153.png
# upload: test/safety_bicycle_s_000280.png to s3://sagemaker-us-east-1-465430730249/test/safety_bicycle_s_000280.png
# upload: test/safety_bike_s_000438.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_000438.png
# upload: test/safety_bike_s_000390.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_000390.png
# upload: test/safety_bicycle_s_001286.png to s3://sagemaker-us-east-1-465430730249/test/safety_bicycle_s_001286.png
# upload: test/safety_bike_s_000488.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_000488.png
# upload: test/safety_bike_s_001065.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_001065.png
# upload: test/safety_bike_s_000541.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_000541.png
# upload: test/safety_bike_s_001088.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_001088.png
# upload: test/safety_bike_s_001481.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_001481.png
# upload: test/safety_bike_s_000540.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_000540.png
# upload: test/safety_bike_s_000699.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_000699.png
# upload: test/safety_bike_s_001087.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_001087.png
# upload: test/safety_bike_s_000791.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_000791.png
# upload: test/safety_bike_s_001132.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_001132.png
# upload: test/velocipede_s_000292.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_000292.png
# upload: test/velocipede_s_000001.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_000001.png
# upload: test/velocipede_s_000863.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_000863.png
# upload: test/trail_bike_s_000073.png to s3://sagemaker-us-east-1-465430730249/test/trail_bike_s_000073.png
# upload: test/safety_bike_s_001253.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_001253.png
# upload: test/velocipede_s_000041.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_000041.png
# upload: test/velocipede_s_000369.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_000369.png
# upload: test/safety_bike_s_001690.png to s3://sagemaker-us-east-1-465430730249/test/safety_bike_s_001690.png
# upload: test/velocipede_s_001201.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_001201.png
# upload: test/velocipede_s_000106.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_000106.png
# upload: test/velocipede_s_001277.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_001277.png
# upload: test/velocipede_s_001335.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_001335.png
# upload: test/velocipede_s_001699.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_001699.png
# upload: test/velocipede_s_001466.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_001466.png
# upload: test/velocipede_s_001355.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_001355.png
# upload: test/velocipede_s_001744.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_001744.png
# upload: test/velocipede_s_001232.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_001232.png
# upload: test/velocipede_s_001379.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_001379.png
# upload: test/velocipede_s_001633.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_001633.png
# upload: test/velocipede_s_001790.png to s3://sagemaker-us-east-1-465430730249/test/velocipede_s_001790.png

# %% [markdown]
# And that's it! You can check the bucket and verify that the items were uploaded.
#
# ## Model Training
#
# For Image Classification, Sagemaker [also expects metadata](https://docs.aws.amazon.com/sagemaker/latest/dg/image-classification.html) e.g. in the form of TSV files with labels and filepaths. We can generate these using our Pandas DataFrames from earlier:

# %%
def to_metadata_file(df, prefix):
    df["s3_path"] = df["filenames"]
    df["labels"] = df["labels"].apply(lambda x: 0 if x==8 else 1)
    return df[["row", "labels", "s3_path"]].to_csv(
        f"{prefix}.lst", sep="\t", index=False, header=False
    )
    
to_metadata_file(df_train.copy(), "train")
to_metadata_file(df_test.copy(), "test")

# %% [markdown]
# We can also upload our manifest files:

# %%
import boto3

# Upload files
boto3.Session().resource('s3').Bucket(
    bucket).Object('train.lst').upload_file('./train.lst')
boto3.Session().resource('s3').Bucket(
    bucket).Object('test.lst').upload_file('./test.lst')
# Out:
# [04/14/25 10:02:36] INFO     Found credentials from IAM Role:                                   ]8;id=477284;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=448919;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
#                     INFO     Found credentials from IAM Role:                                   ]8;id=746366;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=548950;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole

# %% [markdown]
# Using the `bucket` and `region` info we can get the latest prebuilt container to run our training job, and define an output location on our s3 bucket for the model. Use the `image_uris` function from the SageMaker SDK to retrieve the latest `image-classification` image below:

# %%
# Use the image_uris function to retrieve the latest 'image-classification' image 
algo_image = sagemaker.image_uris.retrieve(framework='image-classification', region=region)
s3_output_location = f"s3://{bucket}/models/image_model"
# Out:
# [04/14/25 10:05:23] INFO     Same images used for training and inference. Defaulting to image     ]8;id=181900;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=582747;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/image_uris.py#393\393]8;;\
#                              scope: inference.
#                     INFO     Ignoring unnecessary instance type: None.                            ]8;id=812551;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=970687;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/image_uris.py#530\530]8;;\

# %% [markdown]
# We're ready to create an estimator! Create an estimator `img_classifier_model` that uses one instance of `ml.p3.2xlarge`. Ensure that y ou use the output location we defined above - we'll be referring to that later!

# %%
img_classifier_model=sagemaker.estimator.Estimator(
    image_uri=algo_image, 
    role=role, 
    instance_count=1, 
    instance_type='ml.p3.2xlarge',
    output_path=s3_output_location
)
# Out:
# [04/14/25 10:07:03] INFO     Found credentials from IAM Role:                                   ]8;id=150818;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=892186;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole
# [04/14/25 10:07:04] INFO     Found credentials from IAM Role:                                   ]8;id=628233;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=831114;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/credentials.py#1132\1132]8;;\
#                              BaseNotebookInstanceEc2InstanceRole

# %% [markdown]
# We can also set a few key hyperparameters and define the inputs for our model:

# %%
img_classifier_model.set_hyperparameters(
    image_shape='3,32,32', # 3 x 32 x 32 images
    num_classes=2, # bicycle or motorcycle
    num_training_samples=1000 # rows of df_train
)

# %% [markdown]
# The `image-classification` image uses four input channels with very specific input parameters. For convenience, we've provided them below:

# %%
from sagemaker.debugger import Rule, rule_configs
from sagemaker.session import TrainingInput
model_inputs = {
        "train": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train/",
            content_type="application/x-image"
        ),
        "validation": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test/",
            content_type="application/x-image"
        ),
        "train_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train.lst",
            content_type="application/x-image"
        ),
        "validation_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test.lst",
            content_type="application/x-image"
        )
}

# %% [markdown]
# Great, now we can train the model using the model_inputs. In the cell below, call the `fit` method on our model,:

# %%
## TODO: train your model
img_classifier_model.fit(model_inputs)
# Out:
# [04/14/25 10:30:33] INFO     SageMaker Python SDK will collect telemetry to help us better  ]8;id=983559;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/telemetry/telemetry_logging.py\telemetry_logging.py]8;;\:]8;id=15315;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/telemetry/telemetry_logging.py#91\91]8;;\
#                              understand our user's needs, diagnose issues, and deliver
#                              additional features.
#                              To opt out of telemetry, please disable via TelemetryOptOut
#                              parameter in SDK defaults config. For more information, refer
#                              to
#                              https://sagemaker.readthedocs.io/en/stable/overview.html#confi
#                              guring-and-using-defaults-with-the-sagemaker-python-sdk.
#                     INFO     Creating training-job with name:                                       ]8;id=627489;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=172903;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py#1042\1042]8;;\
#                              image-classification-2025-04-14-10-30-33-445
# 2025-04-14 10:30:37 Starting - Starting the training job
# 2025-04-14 10:30:37 Pending - Training job waiting for capacity.........
# 2025-04-14 10:32:08 Pending - Preparing the instances for training...
# 2025-04-14 10:32:38 Downloading - Downloading input data...
# 2025-04-14 10:32:58 Downloading - Downloading the training image..................
# 2025-04-14 10:36:10 Training - Training image download completed. Training in progress.....Docker entrypoint called with argument(s): train
# Running default environment configuration script
# Nvidia gpu devices, drivers and cuda toolkit versions (only available on hosts with GPU):
# Mon Apr 14 10:36:34 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.144.03             Driver Version: 550.144.03     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100-SXM2-16GB           On  |   00000000:00:1E.0 Off |                    0 |
# | N/A   27C    P0             24W /  300W |       1MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Checking for nvidia driver and cuda compatibility.
# CUDA Compatibility driver provided.
# Proceeding with compatibility check between driver, cuda-toolkit and cuda-compat.
# Detected cuda-toolkit version: 11.1.
# Detected cuda-compat version: 455.32.00.
# Detected Nvidia driver version: 550.144.03.
# Nvidia driver compatible with cuda-toolkit. Disabling cuda-compat.
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# [04/14/2025 10:36:38 INFO 140064873248576] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/image_classification/default-input.json: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,224,224', 'precision_dtype': 'float32'}
# [04/14/2025 10:36:38 INFO 140064873248576] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'image_shape': '3,32,32', 'num_classes': '2', 'num_training_samples': '1000'}
# [04/14/2025 10:36:38 INFO 140064873248576] Final configuration: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,32,32', 'precision_dtype': 'float32', 'num_classes': '2', 'num_training_samples': '1000'}
# [04/14/2025 10:36:38 INFO 140064873248576] Searching for .lst files in /opt/ml/input/data/train_lst.
# [04/14/2025 10:36:38 INFO 140064873248576] Creating record files for train.lst
# [04/14/2025 10:36:38 INFO 140064873248576] Done creating record files...
# [04/14/2025 10:36:38 INFO 140064873248576] Searching for .lst files in /opt/ml/input/data/validation_lst.
# [04/14/2025 10:36:38 INFO 140064873248576] Creating record files for test.lst
# [04/14/2025 10:36:38 INFO 140064873248576] Done creating record files...
# [04/14/2025 10:36:38 INFO 140064873248576] use_pretrained_model: 0
# [04/14/2025 10:36:38 INFO 140064873248576] multi_label: 0
# [04/14/2025 10:36:38 INFO 140064873248576] Performing random weight initialization
# [04/14/2025 10:36:38 INFO 140064873248576] ---- Parameters ----
# [04/14/2025 10:36:38 INFO 140064873248576] num_layers: 152
# [04/14/2025 10:36:38 INFO 140064873248576] data type: <class 'numpy.float32'>
# [04/14/2025 10:36:38 INFO 140064873248576] epochs: 30
# [04/14/2025 10:36:38 INFO 140064873248576] optimizer: sgd
# [04/14/2025 10:36:38 INFO 140064873248576] momentum: 0.9
# [04/14/2025 10:36:38 INFO 140064873248576] weight_decay: 0.0001
# [04/14/2025 10:36:38 INFO 140064873248576] learning_rate: 0.1
# [04/14/2025 10:36:38 INFO 140064873248576] num_training_samples: 1000
# [04/14/2025 10:36:38 INFO 140064873248576] mini_batch_size: 32
# [04/14/2025 10:36:38 INFO 140064873248576] image_shape: 3,32,32
# [04/14/2025 10:36:38 INFO 140064873248576] num_classes: 2
# [04/14/2025 10:36:38 INFO 140064873248576] augmentation_type: None
# [04/14/2025 10:36:38 INFO 140064873248576] kv_store: device
# [04/14/2025 10:36:38 INFO 140064873248576] checkpoint_frequency not set, will store the best model
# [04/14/2025 10:36:38 INFO 140064873248576] --------------------
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [04/14/2025 10:36:38 INFO 140064873248576] Setting number of threads: 7
# [10:36:42] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.441.0/AL2_x86_64/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [04/14/2025 10:36:48 INFO 140064873248576] Epoch[0] Batch [20]#011Speed: 123.816 samples/sec#011accuracy=0.550595
# [04/14/2025 10:36:49 INFO 140064873248576] Epoch[0] Train-accuracy=0.602823
# [04/14/2025 10:36:49 INFO 140064873248576] Epoch[0] Time cost=6.793
# [04/14/2025 10:36:50 INFO 140064873248576] Epoch[0] Validation-accuracy=0.494792
# [04/14/2025 10:36:50 INFO 140064873248576] Storing the best model with validation accuracy: 0.494792
# [04/14/2025 10:36:50 INFO 140064873248576] Saved checkpoint to "/opt/ml/model/image-classification-0001.params"
# [04/14/2025 10:36:54 INFO 140064873248576] Epoch[1] Batch [20]#011Speed: 187.895 samples/sec#011accuracy=0.702381
# [04/14/2025 10:36:55 INFO 140064873248576] Epoch[1] Train-accuracy=0.702621
# [04/14/2025 10:36:55 INFO 140064873248576] Epoch[1] Time cost=5.032
# [04/14/2025 10:36:56 INFO 140064873248576] Epoch[1] Validation-accuracy=0.588542
# [04/14/2025 10:36:56 INFO 140064873248576] Storing the best model with validation accuracy: 0.588542
# [04/14/2025 10:36:56 INFO 140064873248576] Saved checkpoint to "/opt/ml/model/image-classification-0002.params"
# [04/14/2025 10:37:00 INFO 140064873248576] Epoch[2] Batch [20]#011Speed: 194.535 samples/sec#011accuracy=0.683036
# [04/14/2025 10:37:01 INFO 140064873248576] Epoch[2] Train-accuracy=0.703629
# [04/14/2025 10:37:01 INFO 140064873248576] Epoch[2] Time cost=4.906
# [04/14/2025 10:37:02 INFO 140064873248576] Epoch[2] Validation-accuracy=0.781250
# [04/14/2025 10:37:02 INFO 140064873248576] Storing the best model with validation accuracy: 0.781250
# [04/14/2025 10:37:02 INFO 140064873248576] Saved checkpoint to "/opt/ml/model/image-classification-0003.params"
# [04/14/2025 10:37:06 INFO 140064873248576] Epoch[3] Batch [20]#011Speed: 191.259 samples/sec#011accuracy=0.738095
# [04/14/2025 10:37:07 INFO 140064873248576] Epoch[3] Train-accuracy=0.768145
# [04/14/2025 10:37:07 INFO 140064873248576] Epoch[3] Time cost=4.970
# [04/14/2025 10:37:08 INFO 140064873248576] Epoch[3] Validation-accuracy=0.825893
# [04/14/2025 10:37:08 INFO 140064873248576] Storing the best model with validation accuracy: 0.825893
# [04/14/2025 10:37:09 INFO 140064873248576] Saved checkpoint to "/opt/ml/model/image-classification-0004.params"
# [04/14/2025 10:37:12 INFO 140064873248576] Epoch[4] Batch [20]#011Speed: 193.607 samples/sec#011accuracy=0.773810
# [04/14/2025 10:37:13 INFO 140064873248576] Epoch[4] Train-accuracy=0.771169
# [04/14/2025 10:37:13 INFO 140064873248576] Epoch[4] Time cost=4.919
# [04/14/2025 10:37:14 INFO 140064873248576] Epoch[4] Validation-accuracy=0.828125
# [04/14/2025 10:37:14 INFO 140064873248576] Storing the best model with validation accuracy: 0.828125
# [04/14/2025 10:37:15 INFO 140064873248576] Saved checkpoint to "/opt/ml/model/image-classification-0005.params"
# [04/14/2025 10:37:18 INFO 140064873248576] Epoch[5] Batch [20]#011Speed: 194.404 samples/sec#011accuracy=0.796131
# [04/14/2025 10:37:20 INFO 140064873248576] Epoch[5] Train-accuracy=0.780242
# [04/14/2025 10:37:20 INFO 140064873248576] Epoch[5] Time cost=4.908
# [04/14/2025 10:37:20 INFO 140064873248576] Epoch[5] Validation-accuracy=0.838542
# [04/14/2025 10:37:20 INFO 140064873248576] Storing the best model with validation accuracy: 0.838542
# [04/14/2025 10:37:21 INFO 140064873248576] Saved checkpoint to "/opt/ml/model/image-classification-0006.params"
# [04/14/2025 10:37:24 INFO 140064873248576] Epoch[6] Batch [20]#011Speed: 194.183 samples/sec#011accuracy=0.822917
# [04/14/2025 10:37:26 INFO 140064873248576] Epoch[6] Train-accuracy=0.811492
# [04/14/2025 10:37:26 INFO 140064873248576] Epoch[6] Time cost=4.902
# [04/14/2025 10:37:26 INFO 140064873248576] Epoch[6] Validation-accuracy=0.807292
# [04/14/2025 10:37:30 INFO 140064873248576] Epoch[7] Batch [20]#011Speed: 193.319 samples/sec#011accuracy=0.813988
# [04/14/2025 10:37:31 INFO 140064873248576] Epoch[7] Train-accuracy=0.818548
# [04/14/2025 10:37:31 INFO 140064873248576] Epoch[7] Time cost=4.931
# [04/14/2025 10:37:32 INFO 140064873248576] Epoch[7] Validation-accuracy=0.799107
# [04/14/2025 10:37:36 INFO 140064873248576] Epoch[8] Batch [20]#011Speed: 191.148 samples/sec#011accuracy=0.831845
# [04/14/2025 10:37:37 INFO 140064873248576] Epoch[8] Train-accuracy=0.828629
# [04/14/2025 10:37:37 INFO 140064873248576] Epoch[8] Time cost=4.962
# [04/14/2025 10:37:38 INFO 140064873248576] Epoch[8] Validation-accuracy=0.817708
# [04/14/2025 10:37:42 INFO 140064873248576] Epoch[9] Batch [20]#011Speed: 193.662 samples/sec#011accuracy=0.821429
# [04/14/2025 10:37:43 INFO 140064873248576] Epoch[9] Train-accuracy=0.821573
# [04/14/2025 10:37:43 INFO 140064873248576] Epoch[9] Time cost=4.906
# [04/14/2025 10:37:44 INFO 140064873248576] Epoch[9] Validation-accuracy=0.802083
# [04/14/2025 10:37:47 INFO 140064873248576] Epoch[10] Batch [20]#011Speed: 192.969 samples/sec#011accuracy=0.852679
# [04/14/2025 10:37:49 INFO 140064873248576] Epoch[10] Train-accuracy=0.849798
# [04/14/2025 10:37:49 INFO 140064873248576] Epoch[10] Time cost=4.931
# [04/14/2025 10:37:50 INFO 140064873248576] Epoch[10] Validation-accuracy=0.833333
# [04/14/2025 10:37:53 INFO 140064873248576] Epoch[11] Batch [20]#011Speed: 193.437 samples/sec#011accuracy=0.833333
# [04/14/2025 10:37:55 INFO 140064873248576] Epoch[11] Train-accuracy=0.827621
# [04/14/2025 10:37:55 INFO 140064873248576] Epoch[11] Time cost=4.946
# [04/14/2025 10:37:55 INFO 140064873248576] Epoch[11] Validation-accuracy=0.816964
# [04/14/2025 10:37:59 INFO 140064873248576] Epoch[12] Batch [20]#011Speed: 193.170 samples/sec#011accuracy=0.873512
# [04/14/2025 10:38:01 INFO 140064873248576] Epoch[12] Train-accuracy=0.869960
# [04/14/2025 10:38:01 INFO 140064873248576] Epoch[12] Time cost=4.960
# [04/14/2025 10:38:01 INFO 140064873248576] Epoch[12] Validation-accuracy=0.807292
# [04/14/2025 10:38:05 INFO 140064873248576] Epoch[13] Batch [20]#011Speed: 192.252 samples/sec#011accuracy=0.857143
# [04/14/2025 10:38:07 INFO 140064873248576] Epoch[13] Train-accuracy=0.862903
# [04/14/2025 10:38:07 INFO 140064873248576] Epoch[13] Time cost=4.943
# [04/14/2025 10:38:07 INFO 140064873248576] Epoch[13] Validation-accuracy=0.828125
# [04/14/2025 10:38:11 INFO 140064873248576] Epoch[14] Batch [20]#011Speed: 193.929 samples/sec#011accuracy=0.922619
# [04/14/2025 10:38:13 INFO 140064873248576] Epoch[14] Train-accuracy=0.895161
# [04/14/2025 10:38:13 INFO 140064873248576] Epoch[14] Time cost=4.921
# [04/14/2025 10:38:13 INFO 140064873248576] Epoch[14] Validation-accuracy=0.833333
# [04/14/2025 10:38:17 INFO 140064873248576] Epoch[15] Batch [20]#011Speed: 193.116 samples/sec#011accuracy=0.903274
# [04/14/2025 10:38:19 INFO 140064873248576] Epoch[15] Train-accuracy=0.894153
# [04/14/2025 10:38:19 INFO 140064873248576] Epoch[15] Time cost=4.936
# [04/14/2025 10:38:19 INFO 140064873248576] Epoch[15] Validation-accuracy=0.821429
# [04/14/2025 10:38:23 INFO 140064873248576] Epoch[16] Batch [20]#011Speed: 192.185 samples/sec#011accuracy=0.936012
# [04/14/2025 10:38:24 INFO 140064873248576] Epoch[16] Train-accuracy=0.916331
# [04/14/2025 10:38:24 INFO 140064873248576] Epoch[16] Time cost=4.951
# [04/14/2025 10:38:25 INFO 140064873248576] Epoch[16] Validation-accuracy=0.817708
# [04/14/2025 10:38:29 INFO 140064873248576] Epoch[17] Batch [20]#011Speed: 193.995 samples/sec#011accuracy=0.934524
# [04/14/2025 10:38:30 INFO 140064873248576] Epoch[17] Train-accuracy=0.938508
# [04/14/2025 10:38:30 INFO 140064873248576] Epoch[17] Time cost=4.906
# [04/14/2025 10:38:31 INFO 140064873248576] Epoch[17] Validation-accuracy=0.807292
# [04/14/2025 10:38:35 INFO 140064873248576] Epoch[18] Batch [20]#011Speed: 195.142 samples/sec#011accuracy=0.910714
# [04/14/2025 10:38:36 INFO 140064873248576] Epoch[18] Train-accuracy=0.912298
# [04/14/2025 10:38:36 INFO 140064873248576] Epoch[18] Time cost=4.895
# [04/14/2025 10:38:37 INFO 140064873248576] Epoch[18] Validation-accuracy=0.791667
# [04/14/2025 10:38:40 INFO 140064873248576] Epoch[19] Batch [20]#011Speed: 193.386 samples/sec#011accuracy=0.934524
# [04/14/2025 10:38:42 INFO 140064873248576] Epoch[19] Train-accuracy=0.936492
# [04/14/2025 10:38:42 INFO 140064873248576] Epoch[19] Time cost=4.938
# [04/14/2025 10:38:43 INFO 140064873248576] Epoch[19] Validation-accuracy=0.825893
# [04/14/2025 10:38:46 INFO 140064873248576] Epoch[20] Batch [20]#011Speed: 192.334 samples/sec#011accuracy=0.968750
# [04/14/2025 10:38:48 INFO 140064873248576] Epoch[20] Train-accuracy=0.954637
# [04/14/2025 10:38:48 INFO 140064873248576] Epoch[20] Time cost=4.955
# [04/14/2025 10:38:48 INFO 140064873248576] Epoch[20] Validation-accuracy=0.828125
# [04/14/2025 10:38:52 INFO 140064873248576] Epoch[21] Batch [20]#011Speed: 193.419 samples/sec#011accuracy=0.938988
# [04/14/2025 10:38:54 INFO 140064873248576] Epoch[21] Train-accuracy=0.936492
# [04/14/2025 10:38:54 INFO 140064873248576] Epoch[21] Time cost=4.946
# [04/14/2025 10:38:54 INFO 140064873248576] Epoch[21] Validation-accuracy=0.822917
# [04/14/2025 10:38:58 INFO 140064873248576] Epoch[22] Batch [20]#011Speed: 195.036 samples/sec#011accuracy=0.956845
# [04/14/2025 10:39:00 INFO 140064873248576] Epoch[22] Train-accuracy=0.948589
# [04/14/2025 10:39:00 INFO 140064873248576] Epoch[22] Time cost=4.885
# [04/14/2025 10:39:00 INFO 140064873248576] Epoch[22] Validation-accuracy=0.817708
# [04/14/2025 10:39:04 INFO 140064873248576] Epoch[23] Batch [20]#011Speed: 192.936 samples/sec#011accuracy=0.964286
# [04/14/2025 10:39:05 INFO 140064873248576] Epoch[23] Train-accuracy=0.960685
# [04/14/2025 10:39:05 INFO 140064873248576] Epoch[23] Time cost=4.933
# [04/14/2025 10:39:06 INFO 140064873248576] Epoch[23] Validation-accuracy=0.803571
# [04/14/2025 10:39:10 INFO 140064873248576] Epoch[24] Batch [20]#011Speed: 192.256 samples/sec#011accuracy=0.961310
# [04/14/2025 10:39:11 INFO 140064873248576] Epoch[24] Train-accuracy=0.963710
# [04/14/2025 10:39:11 INFO 140064873248576] Epoch[24] Time cost=4.956
# [04/14/2025 10:39:12 INFO 140064873248576] Epoch[24] Validation-accuracy=0.854167
# [04/14/2025 10:39:12 INFO 140064873248576] Storing the best model with validation accuracy: 0.854167
# [04/14/2025 10:39:13 INFO 140064873248576] Saved checkpoint to "/opt/ml/model/image-classification-0025.params"
# [04/14/2025 10:39:16 INFO 140064873248576] Epoch[25] Batch [20]#011Speed: 192.501 samples/sec#011accuracy=0.952381
# [04/14/2025 10:39:17 INFO 140064873248576] Epoch[25] Train-accuracy=0.954637
# [04/14/2025 10:39:17 INFO 140064873248576] Epoch[25] Time cost=4.940
# [04/14/2025 10:39:18 INFO 140064873248576] Epoch[25] Validation-accuracy=0.760417
# [04/14/2025 10:39:22 INFO 140064873248576] Epoch[26] Batch [20]#011Speed: 193.730 samples/sec#011accuracy=0.983631
# [04/14/2025 10:39:23 INFO 140064873248576] Epoch[26] Train-accuracy=0.983871
# [04/14/2025 10:39:23 INFO 140064873248576] Epoch[26] Time cost=4.936
# [04/14/2025 10:39:24 INFO 140064873248576] Epoch[26] Validation-accuracy=0.812500
# [04/14/2025 10:39:28 INFO 140064873248576] Epoch[27] Batch [20]#011Speed: 192.712 samples/sec#011accuracy=0.988095
# [04/14/2025 10:39:29 INFO 140064873248576] Epoch[27] Train-accuracy=0.982863
# [04/14/2025 10:39:29 INFO 140064873248576] Epoch[27] Time cost=4.939
# [04/14/2025 10:39:30 INFO 140064873248576] Epoch[27] Validation-accuracy=0.834821
# [04/14/2025 10:39:33 INFO 140064873248576] Epoch[28] Batch [20]#011Speed: 194.013 samples/sec#011accuracy=0.989583
# [04/14/2025 10:39:35 INFO 140064873248576] Epoch[28] Train-accuracy=0.983871
# [04/14/2025 10:39:35 INFO 140064873248576] Epoch[28] Time cost=4.914
# [04/14/2025 10:39:35 INFO 140064873248576] Epoch[28] Validation-accuracy=0.848958
# [04/14/2025 10:39:39 INFO 140064873248576] Epoch[29] Batch [20]#011Speed: 193.085 samples/sec#011accuracy=0.980655
# [04/14/2025 10:39:41 INFO 140064873248576] Epoch[29] Train-accuracy=0.976815
# [04/14/2025 10:39:41 INFO 140064873248576] Epoch[29] Time cost=4.921
# [04/14/2025 10:39:41 INFO 140064873248576] Epoch[29] Validation-accuracy=0.833333
#
# 2025-04-14 10:40:04 Uploading - Uploading generated training model
# 2025-04-14 10:40:04 Completed - Training job completed
# Training seconds: 446
# Billable seconds: 446

# %% [markdown]
# If all goes well, you'll end up with a model topping out above `.8` validation accuracy. With only 1000 training samples in the CIFAR dataset, that's pretty good. We could definitely pursue data augmentation & gathering more samples to help us improve further, but for now let's proceed to deploy our model.
#
# ### Getting ready to deploy
#
# To begin with, let's configure Model Monitor to track our deployment. We'll define a `DataCaptureConfig` below:

# %%
from sagemaker.model_monitor import DataCaptureConfig

data_capture_config = DataCaptureConfig(
    enable_capture=True,
    sampling_percentage=100,
    destination_s3_uri=f"s3://{bucket}/data_capture"
)

# %% [markdown]
# Note the `destination_s3_uri` parameter: At the end of the project, we can explore the `data_capture` directory in S3 to find crucial data about the inputs and outputs Model Monitor has observed on our model endpoint over time.
#
# With that done, deploy your model on a single `ml.m5.xlarge` instance with the data capture config attached:

# %%
deployment = img_classifier_model.deploy(
    initial_instance_count=1,
    instance_type='ml.m5.xlarge',
    data_capture_config=data_capture_config
    )

endpoint = deployment.endpoint_name
print(endpoint)
# Out:
# [04/14/25 10:45:21] INFO     Creating model with name: image-classification-2025-04-14-10-45-21-476 ]8;id=748220;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=184493;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py#4094\4094]8;;\
# [04/14/25 10:45:22] INFO     Creating endpoint-config with name                                     ]8;id=631148;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=587362;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py#6019\6019]8;;\
#                              image-classification-2025-04-14-10-45-21-476
#                     INFO     Creating endpoint with name                                            ]8;id=429868;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=978916;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sagemaker/session.py#4841\4841]8;;\
#                              image-classification-2025-04-14-10-45-21-476
# ----------!image-classification-2025-04-14-10-45-21-476

# %% [markdown]
# Note the endpoint name for later as well.
#
# Next, instantiate a Predictor:

# %%
from sagemaker.predictor import Predictor

predictor = Predictor(endpoint_name=endpoint)

# %% [markdown]
# In the code snippet below we are going to prepare one of your saved images for prediction. Use the predictor to process the `payload`.

# %%
from sagemaker.serializers import IdentitySerializer
import base64

predictor.serializer = IdentitySerializer("image/png")
with open("./test/bicycle_s_001789.png", "rb") as f:
    payload = f.read()

    
inference = predictor.predict(payload)

# %% [markdown]
# Your `inference` object is an array of two values, the predicted probability value for each of your classes (bicycle and motorcycle respectively.) So, for example, a value of `b'[0.91, 0.09]'` indicates the probability of being a bike is 91% and being a motorcycle is 9%.

# %%
print(inference)
# Out:
# b'[0.9960492253303528, 0.003950784914195538]'

# %% [markdown]
# ### Draft Lambdas and Step Function Workflow
#
# Your operations team uses Step Functions to orchestrate serverless workflows. One of the nice things about Step Functions is that [workflows can call other workflows](https://docs.aws.amazon.com/step-functions/latest/dg/connect-stepfunctions.html), so the team can easily plug your workflow into the broader production architecture for Scones Unlimited.
#
# In this next stage you're going to write and deploy three Lambda functions, and then use the Step Functions visual editor to chain them together! Our functions are going to work with a simple data object:
#
# ```python
# {
#     "inferences": [], # Output of predictor.predict
#     "s3_key": "", # Source data S3 key
#     "s3_bucket": "", # Source data S3 bucket
#     "image_data": ""  # base64 encoded string containing the image data
# }
# ```
#
# A good test object that you can use for Lambda tests and Step Function executions, throughout the next section, might look like this:
#
# ```python
# {
#   "image_data": "",
#   "s3_bucket": MY_BUCKET_NAME, # Fill in with your bucket
#   "s3_key": "test/bicycle_s_000513.png"
# }
# ```
#
# Using these fields, your functions can read and write the necessary data to execute your workflow. Let's start with the first function. Your first Lambda function will copy an object from S3, base64 encode it, and then return it to the step function as `image_data` in an event.
#
# Go to the Lambda dashboard and create a new Lambda function with a descriptive name like "serializeImageData" and select thr 'Python 3.8' runtime. Add the same permissions as the SageMaker role you created earlier. (Reminder: you do this in the Configuration tab under "Permissions"). Once you're ready, use the starter code below to craft your Lambda handler:
#
# ```python
# import json
# import boto3
# import base64
#
# s3 = boto3.client('s3')
#
# def lambda_handler(event, context):
#     """A function to serialize target data from S3"""
#
#     # Get the s3 address from the Step Function event input
#     key = ## TODO: fill in
#     bucket = ## TODO: fill in
#
#     # Download the data from s3 to /tmp/image.png
#     ## TODO: fill in
#
#     # We read the data from a file
#     with open("/tmp/image.png", "rb") as f:
#         image_data = base64.b64encode(f.read())
#
#     # Pass the data back to the Step Function
#     print("Event:", event.keys())
#     return {
#         'statusCode': 200,
#         'body': {
#             "image_data": image_data,
#             "s3_bucket": bucket,
#             "s3_key": key,
#             "inferences": []
#         }
#     }
# ```
#
# The next function is responsible for the classification part - we're going to take the image output from the previous function, decode it, and then pass inferences back to the the Step Function.
#
# Because this Lambda will have runtime dependencies (i.e. the SageMaker SDK) you'll need to package them in your function. *Key reading:* https://docs.aws.amazon.com/lambda/latest/dg/python-package-create.html#python-package-create-with-dependency
#
# Create a new Lambda function with the same rights and a descriptive name, then fill in the starter code below for your classifier Lambda.
#
# ```python
# import json
# import sagemaker
# import base64
# from sagemaker.serializers import IdentitySerializer
#
# # Fill this in with the name of your deployed model
# ENDPOINT = ## TODO: fill in
#
# def lambda_handler(event, context):
#
#     # Decode the image data
#     image = base64.b64decode(## TODO: fill in)
#
#     # Instantiate a Predictor
#     predictor = ## TODO: fill in
#
#     # For this model the IdentitySerializer needs to be "image/png"
#     predictor.serializer = IdentitySerializer("image/png")
#
#     # Make a prediction:
#     inferences = ## TODO: fill in
#
#     # We return the data back to the Step Function
#     event["inferences"] = inferences.decode('utf-8')
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
#
# Finally, we need to filter low-confidence inferences. Define a threshold between 1.00 and 0.000 for your model: what is reasonble for you? If the model predicts at `.70` for it's highest confidence label, do we want to pass that inference along to downstream systems? Make one last Lambda function and tee up the same permissions:
#
# ```python
# import json
#
#
# THRESHOLD = .93
#
#
# def lambda_handler(event, context):
#
#     # Grab the inferences from the event
#     inferences = ## TODO: fill in
#
#     # Check if any values in our inferences are above THRESHOLD
#     meets_threshold = ## TODO: fill in
#
#     # If our threshold is met, pass our data back out of the
#     # Step Function, else, end the Step Function with an error
#     if meets_threshold:
#         pass
#     else:
#         raise("THRESHOLD_CONFIDENCE_NOT_MET")
#
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
# Once you have tested the lambda functions, save the code for each lambda function in a python script called 'lambda.py'.
#
# With your lambdas in place, you can use the Step Functions visual editor to construct a workflow that chains them together. In the Step Functions console you'll have the option to author a Standard step function *Visually*.
#
# When the visual editor opens, you'll have many options to add transitions in your workflow. We're going to keep it simple and have just one: to invoke Lambda functions. Add three of them chained together. For each one, you'll be able to select the Lambda functions you just created in the proper order, filter inputs and outputs, and give them descriptive names.
#
# Make sure that you:
#
# 1. Are properly filtering the inputs and outputs of your invokations (e.g. `$.body`)
# 2. Take care to remove the error handling from the last function - it's supposed to "fail loudly" for your operations colleagues!
#
# Take a screenshot of your working step function in action and export the step function as JSON for your submission package.

# %% [markdown]
# Great! Now you can use the files in `./test` as test files for our workflow. Depending on our threshold, our workflow should reliably pass predictions about images from `./test` on to downstream systems, while erroring out for inferences below our confidence threshold!
#
# ### Testing and Evaluation
#
# Do several step function invokations using data from the `./test` folder. This process should give you confidence that the workflow both *succeeds* AND *fails* as expected. In addition, SageMaker Model Monitor will generate recordings of your data and inferences which we can visualize.
#
# Here's a function that can help you generate test inputs for your invokations:

# %%
import random
import boto3
import json


def generate_test_case():
    # Setup s3 in boto3
    s3 = boto3.resource('s3')
    
    # Randomly pick from sfn or test folders in our bucket
    objects = s3.Bucket(bucket).objects.filter(Prefix="test/")
    
    # Grab any random object key from that folder!
    obj = random.choice([x.key for x in objects])
    
    return json.dumps({
        "image_data": "",
        "s3_bucket": bucket,
        "s3_key": obj
    })
generate_test_case()
# Out:
# '{"image_data": "", "s3_bucket": "sagemaker-us-east-1-465430730249", "s3_key": "test/velocipede_s_001466.png"}'

# %% [markdown]
# In the Step Function dashboard for your new function, you can create new executions and copy in the generated test cases. Do several executions so that you can generate data you can evaluate and visualize.
#
# Once you've done several executions, let's visualize the record of our inferences. Pull in the JSONLines data from your inferences like so:

# %%
from sagemaker.s3 import S3Downloader

# In S3 your data will be saved to a datetime-aware path
# Find a path related to a datetime you're interested in
data_path = 's3://sagemaker-us-east-1-465430730249/data_capture/image-classification-2025-04-14-10-45-21-476/AllTraffic/2025/04/14/17/'

S3Downloader.download(data_path, "captured_data")

# Feel free to repeat this multiple times and pull in more data
# Out:
# ['captured_data/02-34-036-4f21e716-1179-4988-9600-6cfce902505c.jsonl']

# %% [markdown]
# The data are in JSONLines format, where multiple valid JSON objects are stacked on top of eachother in a single `jsonl` file. We'll import an open-source library, `jsonlines` that was purpose built for parsing this format.

# %%
# !pip install jsonlines
import jsonlines
# Out:
# Requirement already satisfied: jsonlines in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (4.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from jsonlines) (23.2.0)

# %% [markdown]
# Now we can extract the data from each of the source files:

# %%
import os

# List the file names we downloaded
file_handles = os.listdir("./captured_data")

# Dump all the data into an array
json_data = []
for jsonl in file_handles:
    with jsonlines.open(f"./captured_data/{jsonl}") as f:
        json_data.append(f.read())

# %% [markdown]
# The data should now be a list of dictionaries, with significant nesting. We'll give you an example of some code that grabs data out of the objects and visualizes it:

# %%
# Define how we'll get our data
def simple_getter(obj):
    inferences = obj["captureData"]["endpointOutput"]["data"]
    timestamp = obj["eventMetadata"]["inferenceTime"]
    return json.loads(inferences), timestamp

simple_getter(json_data[0])
# Out:
# ([0.9993559718132019, 0.0006440181750804186], '2025-04-14T16:24:13Z')

# %% [markdown]
# Finally, here's an example of a visualization you can build with this data. In this last part, you will take some time and build your own - the captured data has the input images, the resulting inferences, and the timestamps.

# %%
# Populate the data for the x and y axis
x = []
y = []
for obj in json_data:
    inference, timestamp = simple_getter(obj)
    
    y.append(max(inference))
    x.append(timestamp)

# Todo: here is an visualization example, take some time to build another visual that helps monitor the result
# Plot the data
plt.scatter(x, y, c=['r' if k<.94 else 'b' for k in y ])
plt.axhline(y=0.94, color='g', linestyle='--')
plt.ylim(bottom=.88)

# Add labels
plt.ylabel("Confidence")
plt.suptitle("Observed Recent Inferences", size=14)
plt.title("Pictured with confidence threshold for production use", size=10)

# Give it some pizzaz!
plt.style.use("Solarize_Light2")
plt.gcf().autofmt_xdate()
# Out:
# [04/14/25 17:11:08] INFO     Using categorical units to plot a list of strings that are all         ]8;id=879773;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/matplotlib/category.py\category.py]8;;\:]8;id=583511;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/matplotlib/category.py#224\224]8;;\
#                              parsable as floats or dates. If these strings should be plotted as
#                              numbers, cast to the appropriate data type before plotting.
#                     INFO     Using categorical units to plot a list of strings that are all         ]8;id=870895;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/matplotlib/category.py\category.py]8;;\:]8;id=686031;file:///home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/matplotlib/category.py#224\224]8;;\
#                              parsable as floats or dates. If these strings should be plotted as
#                              numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# ### Todo: build your own visualization

# %%
plt.figure()

plt.hist(y, bins=30, color='blue')
plt.axvline(0.94, color='red', linestyle='--', label='Threshold')
plt.xlabel("Confidence")
plt.ylabel("Number of Inferences")
plt.title("Distribution of Inference Confidence")
plt.legend()

# %% [markdown]
# ### Congratulations!
#
# You've reached the end of the project. In this project you created an event-drivent ML workflow that can be incorporated into the Scones Unlimited production architecture. You used the SageMaker Estimator API to deploy your SageMaker Model and Endpoint, and you used AWS Lambda and Step Functions to orchestrate your ML workflow. Using SageMaker Model Monitor, you instrumented and observed your Endpoint, and at the end of the project you built a visualization to help stakeholders understand the performance of the Endpoint over time. If you're up for it, you can even go further with these stretch goals:
#
# * Extend your workflow to incorporate more classes: the CIFAR dataset includes other vehicles that Scones Unlimited can identify with this model.
# * Modify your event driven workflow: can you rewrite your Lambda functions so that the workflow can process multiple image inputs in parallel? Can the Step Function "fan out" to accomodate this new workflow?
# * Consider the test data generator we provided for you. Can we use it to create a "dummy data" generator, to simulate a continuous stream of input data? Or a big paralell load of data?
# * What if we want to get notified every time our step function errors out? Can we use the Step Functions visual editor in conjunction with a service like SNS to accomplish this? Try it out!
